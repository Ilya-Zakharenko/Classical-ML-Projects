# %% [markdown]
# # <CENTER> **PROJECT: Semantic text search**
#
# ![header.jpg](attachment:header.jpg)
#
# ---

# %% [markdown]
# #### **Цель и ожидаемый результат:**
#
# Создать систему семантического текстового поиска слов (словосочетаний) в документах, учитывающую не только точное написание, но и смысловое значение.
# Результатом должно быть определение позиции найденного слова/словосочетания в тексте и оценка вероятности совпадения.
#
# Желательно реализовать примитивный веб-интерфейс (UI) для ручного тестирования.
#
# ---
#
# #### **Технические требования:**
#
# * Язык разработки — Python;
#
# * Все тексты — на русском языке, приведены к нижнему регистру, без пунктуации;
#
# * Максимальная длина документа — 30 слов;
#
# * Словосочетания — не более 2 слов в базовой форме.
#
# ---
#
# #### **Этапы работы над проектом:**
#
# Проект будет состоять из трёх частей:
#
# `1.` *Базовый анализ и знакомство с данными*;
#
# `2.` *Очистка данных*;
#
# `3.` *Разведывательный анализ данных (EDA)*;
#
# `4.` *Machine Learning*.
#
# ---

# %% [markdown]
# **Импортируем необходимые библиотеки:**

# %%
# Для работы с данными
import pandas as pd
import numpy as np
import pymorphy3
import re
import joblib
import os
os.environ["USE_TF"] = "0"


# Для построения графиков
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots


from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud
import nltk
from nltk import ngrams
nltk.download('punkt')
nltk.download('stopwords')


# Для построения модели
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer, util
from keybert import KeyBERT
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Загрузка данных:**

# %%
# Ссылка на raw-версию CSV
url = 'https://raw.githubusercontent.com/JarikDev/code_n_conquer/master/src/ml/data/1.csv'

# Загружаем данные
text_data = pd.read_csv(url)

# Копия датасета
text_df = text_data.copy()

# %% [markdown]
# ## <CENTER> **`1.` Базовый анализ и знакомство с данными**
#
# На данном этапе изучим информацию предоставленных данных.

# %% [markdown]
# #### $1.1$
#
# Выведем информацию по таблице:

# %%
# Выводим размеры таблицы
print('Данные имеют следующую размерность:\n')
print('Количество строк: {};\nКоличество признаков (столбцов): {}.'.format(text_df.shape[0], text_df.shape[1]))
print('-' * 40)


# Выведем первые пять строк 
display(text_df.head())
print('-' * 110)
# Out:
# Данные имеют следующую размерность:
#
# Количество строк: 1000;
# Количество признаков (столбцов): 3.
# ----------------------------------------
#                                             doc_text  \
# 0  Твой лучший секс спрятан здесь 🔞  Делюсь канал...
# 1  ⭐️  Кнопка: ⭐️START⭐️(https://t.me/major/start...
# 2  А продолжение где? Правильно. В моем сообществ...
# 3  Тем временем моя авторская телега уверенно в т...
# 4  У меня есть двоюродная сестра, у нее есть сын ...
#
#                                           image2text speech2text
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  девчонки не умеют переписываться sanille они э...         NaN
# 3  10:42 nuil пул telegram ^ 51 142 подписчика 12...         NaN
# 4  т с не ^ е z 8 * \"8 ничего не знала о стендап...         NaN
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### $1.2$
#
# Выведем информацию по признакам:

# %%
# Вывод таблицы
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   doc_text     1000 non-null   object
#  1   image2text   568 non-null    object
#  2   speech2text  338 non-null    object
# dtypes: object(3)
# memory usage: 23.6+ KB

# %% [markdown]
# Подсчитаем количество по типам признаков:

# %%
# Подсчет количества признаков типа 'object', 'int64' и 'float64'      
object_columns_count = text_df.select_dtypes(include = ['object']).shape[1]
int64_columns_count = text_df.select_dtypes(include = ['int64']).shape[1]
float64_columns_count = text_df.select_dtypes(include = ['float64']).shape[1]


# Вывод результата
print('В данных представлены признаки следующих типов:\n')
print(f"Количество признаков типа 'object': {object_columns_count}")
print(f"Количество признаков типа 'int64': {int64_columns_count}")
print(f"Количество признаков типа 'float64': {float64_columns_count}")
# Out:
# В данных представлены признаки следующих типов:
#
# Количество признаков типа 'object': 3
# Количество признаков типа 'int64': 0
# Количество признаков типа 'float64': 0

# %% [markdown]
# #### $1.3$
#
# Выведем описательные характеристики по признакам:

# %%
# Вывод таблицы
text_df.describe()
# Out:
#                                                  doc_text image2text  \
# count                                                1000        568
# unique                                                956        520
# top     Больше меня тут:  ТГ:  https://t.me/sobolevtel...  карта дня
# freq                                                   12          7
#
#                                               speech2text
# count                                                 338
# unique                                                331
# top     Вот и настал долгожданный день. Сегодня с 19.0...
# freq                                                    2

# %% [markdown]
# #### $1.4$
#
# Проверим данные на наличие пропусков:

# %%
# Выводим суммарное количество пропусков
print('Суммарное количество пропусков в данных: {} \n'.format(text_df.isnull().sum().sum()))
print('-' * 50)

# Выводим признаки с сумрным количеством пропусков
print('Информация по количествам пропусков: \n\n{} \n'.format(text_df.isnull().sum()))
print('-' * 50)



# Построим тепловую карту пропусков
# Создаём функцию отображения пропущенных значений на тепловой карте
def missing_values_heatmap(data):
    
    # Рассчитываем количество пропусков
    cols_null_persent = data.isnull().mean() * 100
    cols_with_null = cols_null_persent[cols_null_persent > 0].sort_values(ascending = False)
    print(f'Информация по количествам пропусков в процентах:\n\n{cols_with_null}')
    print('-' * 50)
    
    # Задаём параметры графика
    colors = sns.color_palette('coolwarm')
    fig = plt.figure(figsize = (30, 13))
    cols = cols_with_null.index
    
    # Строим тепловую карту
    ax = sns.heatmap(
        data = data[cols].isnull(),
        cmap = sns.color_palette(colors)
    )
    
    # Задаём название графика
    plt.title('Тепловая карта пропущенных значений', fontsize = 20)
    
    return ax



# Применяем полученную функцию к нашему датасету
missing_values_heatmap(text_df)
# Out:
# Суммарное количество пропусков в данных: 1094
#
# --------------------------------------------------
# Информация по количествам пропусков:
#
# doc_text         0
# image2text     432
# speech2text    662
# dtype: int64
#
# --------------------------------------------------
# Информация по количествам пропусков в процентах:
#
# speech2text    66.2
# image2text     43.2
# dtype: float64
# --------------------------------------------------
# <Axes: title={'center': 'Тепловая карта пропущенных значений'}>

# %% [markdown]
# **Вывод:**
#
# Как видно из полученного графика, количество пропусков в данных составляет от $43$% до $66$%.
#
# Необходима предобработка данных.

# %% [markdown]
# #### $1.5$
#
# Проверяем данные на наличие дубликатов:

# %%
# Создаём список признаков
dupl_columns = list(text_df.columns)


# Создаём маску дубликатов с помощью метода duplicated() и произведём фильтрацию
mask = text_df.duplicated(subset = dupl_columns)
train_duplicates = text_df[mask]
print(f'Число найденных дубликатов: {train_duplicates.shape[0]}')
# Out:
# Число найденных дубликатов: 8

# %% [markdown]
# #### $1.6$
#
# Данные содержат колонку `doc_text` с текстами документов. Мы будем использовать эту колонку для поиска:

# %%
# Выделяем признак 'doc_text' и превращаем его в список
documents = text_df['doc_text'].tolist()



# Выводим результат
print('Данные содержат тексты документов следующего содержания:')
print('-' * 60)
print()

display(documents)
# Out:
# Данные содержат тексты документов следующего содержания:
# ------------------------------------------------------------
# ['Твой лучший секс спрятан здесь 🔞  Делюсь каналом дипломированного сексолога. Крис взломала код классного секса, мастерски раскрепощает, знает миллион горячих техник и лучшие девайсы для взрослых 😻  Самые полезные посты здесь:   Отрезвляющий пост «Я все сама!»   Прокачай наездницу  Ролевая игра «VIP кинотеатр»   Техника оральных ласк 💣   Как занимается сeксом неудобная женщина   Кстати, Крис провела трехдневный безоплатный онлайн интенсив-«От бревна до Богини». Совместно с врачом и владельцем секс-шопа.   Скорее смотри записи, пока не удалила 🔞  https://t.me/sekretskris/1048   Здесь жарче, чем в аду 😈',
#  '⭐️  Кнопка: ⭐️START⭐️(https://t.me/major/start?startapp=1972869792)',
#  'А продолжение где? Правильно. В моем сообществе в ВК. Ссылка в шапке профиля.',
#  'Тем временем моя авторская телега уверенно в тройке сильнейших!!! Компания мощная!!! Ухххх!!! 💪',
#  'У меня есть двоюродная сестра, у нее есть сын Антон, мой двоюродный племянник получается) Он снимает свой подкаст, конечно я пришла его поддержать! Получилось честное и откровенное интервью   Смотрите   https://youtu.be/aIFYXpJaa1Q?si=mh4_BWSK-raKKcmv',
#  'Тем временем моя авторская телега уверенно в тройке сильнейших!!! Компания мощная!!! Ухххх!!! 💪',
#  'МОИ УЧЕНИКИ КО МНЕ ВОЗВРАЩАЮТСЯ   Мои Волшебные 🪄   Вы не представляете, насколько круто и приятно, когда мои ученики с других курсов и потоков вновь возвращаются ко мне на обучение, и тем более, под мое наставничество 😍🔥   Главное преимущество ВИП-тарифа - это мое чуткое руководство, я вам подскажу, направлю и помогу 🫶   Хотите начать путь в мир эзотерики и мантики с опытным наставником? 🔮 тогда жду вас на собеседовании! Переходите по ссылке и записывайтесь ➡️ https://wa.me/79043358533',
#  'На ютюб канале Olympics эти дни и сейчас идут прямые трансляции соревнований (проверяла без vpn).   Видимо, там и Церемонию Открытия покажут.  Вот ссылка. Нужно выбрать вкладку ТРАНСЛЯЦИИ:  https://youtube.com/@olympics?si=DX1TERVaGjgAYeTo  П Olympics Welcome to the Olympics YouTube channel, where the Games never end! 🥇  From the best musical moments at the Olympic Games in our Music Monday series to weekly compilation videos with highlights from the Olympics on Fridays, plus exclusive documentaries about the stories behind the glory, this is where you can find everything about the biggest sporting event in the world. 🔗 https://youtube.com/@olympics?si=DX1TERVaGjgAYeTo',
#  'Смотреть 👇  https://youtu.be/-epu_3sY7Os  П РАЗДЕВАЛКА №12. СЕРГЕЙ ОРЛОВ И АЛЕКСАНДР ПТАШЕНЧУК. БАСКЕТБОЛ ИЛИ БАЦКЕТБОЛ? ВАМ СЮДА https://mediumsport.ru/  Как правильно произносить название нашей любимой игры «баСкетбол» или «баЦкетбол»? У Сереги Орлова есть своя версия! Смотри выпуск "Раздевалки" и  узнаешь, как верный ответ. Да-да Саша Пташенчук тоже был в шоке!  Наш тг: https://t.me/mediumbasket  Хочешь смотреть больше баскетбольных видео? Инсайды, бэкстейджы и не вошедшее будет на канале Medium Basket Shorts, подписывайся! / @mediumbasketshorts 🔗 https://youtu.be/-epu_3sY7Os',
#  'Сегодня день рождения Матвея Кисляка и этот выпуск Молодого подкаста мы готовили как подарок юному армейцу.   Ровно год назад он дебютировал за ЦСКА и забил первый гол. А теперь он свободно рассуждает о жизни, о Гвардиоле и Кройфе, и точно знает, что хотел бы стать тренером, а ведь ему только что исполнилось 19 лет.   Клик, чтобы получить удовольствие от взрослого разговора с юношей. Абсолютное открытие!  https://youtu.be/V4ywWqjkgm8?si=BP4Zt4z4zj2m7Y3l  П КИСЛЯК: МАТЧ ПРОТИВ МАТЕУСА, ИГРЫ В БРАЗИЛИИ И МЕЧТА СТАТЬ ТРЕНЕРОМ | МОЛОДОЙ ПОДКАСТ #2 Матвей Кисляк рассказал Эду и Нагучеву про свою футбольную карьеру. Второй выпуск МОЛОДОГО ПОДКАСТА с восходящей звездой ЦСКА.  Детство в Старом Осколе и соседство с Емельяненко, матч против легенд футбола перед стартом ЧМ-2018, посещение футбольного места силы в Бразилии.   Телега Нагучева: https://t.me/offearth Телега Эда: https://t.me/ededik Ютуб-канал Эда: https://www.youtube.com/@edams19  Следите за ЮФЛ и МФЛ в наших соцсетях и на сайте 👇  Сайт: https://yflrussia.ru ЮФЛ в ВК, а также обзоры, интервью и записи игр тут: https://vk.com/yflrussia МФЛ в ВК, а также обзоры, интервью и записи игр тут: https://vk.com/mflrussia Telegram ЮФЛ: https://t.me/yflrussia Telegram МФЛ: https://t.me/mflrussia Дзен: https://dzen.ru/yfl 🔗 https://youtu.be/V4ywWqjkgm8?si=BP4Zt4z4zj2m7Y3l',
#  'КАКАЯ КАРТА УКАЖЕТ НА МАСИКА? 🥰  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base  Прикреплённые ссылки: 🔗 http://alexeygrishin.com/lenorman_base',
#  'КАКАЯ КАРТА УКАЖЕТ НА МАСИКА? 🥰  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base',
#  'Сегодня (26.07) премьера в 18.00 (мск) - долгожданный выпуск с [id1868874|Евгений Егоров]   https://youtu.be/a4HBdcgpjzI?si=kRUzKulyQ2GP_8fp',
#  'Отзыв от Юлианны🙏🏻\U0001fa77  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base  *Деятельность компании Meta запрещена на территории Российской Федерации и признана экстремистской.  Прикреплённые ссылки: 🔗 http://alexeygrishin.com/lenorman_base',
#  'Таро-прогноз на 26 Июля – Тройка Жезлов.   🔮 Совет: Тройка Жезлов – карта роста, стабильности и успеха. Чего бы не касался вопрос – личных отношений, карьеры, духовного роста – эта карта советует продолжать двигаться вперед, выходить за пределы нынешних границ. По этой карте идут вдохновение и реализация идей, они обретают форму и получают направление. Она обещает благополучный исход дела.   💰 Деньги: Стабильное положение и дальнейшее процветание. Успешное решение вопросов. Прекрасные возможности для дальнейшего улучшения ситуации. Финансовые успехи благодаря разумному поведению. Тройка Жезлов\xa0 означает коммерческий успех, и вообще показывает человека, занимающего прочное положение и имеющего надежный тыл.   \U0001fa77 Любовь: Тройка Жезлов – та карта, которая традиционно считается залогом счастья. Она говорит, что печали и неприятности останутся позади, раскрываются все возможности для построения благополучной жизни, а в отношениях все будет хорошо.\xa0Весеннее настроение и сексуальная гармония.  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base',
#  'Отзыв от Юлианны🙏🏻\U0001fa77  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base  *Деятельность компании Meta запрещена на территории Российской Федерации и признана экстремистской.',
#  'Roast battle на ютубе!   https://youtu.be/LGZLl8lOI8c?si=M5K3uHOyU2paIA2j',
#  'Всегда приветствую появление новых динамовских каналов/страниц/контента.   Сегодня рекомендация подписаться на динамовского болельщика из Эстонии, несмотря на все логистические сложности выбирающегося на игры Динамо.   Неординарный подход к оценке выступления футболистов на примере игры с Факелом.  Прошу!  https://dzen.ru/a/Zp98SLpeixpGBmxJ  П Динамо Москва - Факел. Подробный обзор. Статья автора «futbolofyl» в Дзене ✍: ДинамоМосква – Факел  3-1 Яркое начало Анализируем игру каждого игрока Динамо, решения тренерского штаба, работу судей и комментаторов. 🔗 https://dzen.ru/a/Zp98SLpeixpGBmxJ',
#  'spartakoz https://t.me/spartakoz/9847    ⚡️⚡️⚡️Давно хотел сделать видеопроект о «Спартаке».   И вот с моими партнерами из Winline получилось: вашему вниманию — «Спартак Шоу»!  В первом выпуске вместе с Сабиной Ромбиновной Актериной и Свиным Рылом обсудили поражение от «Оренбурга», но еще:   • дали пару инсайдов по трансферам «Спартака»   • объяснили поведение Соболева и почему «Зенит» не хочет его брать прямо сейчас    • поговорили о Станковиче: почему у него может получиться в «Спартаке»   • разобрали межсезонье, Барко и Виллиана Жозе  • поболтали о том, что ждет «Спартак» очень скоро   • объявили розыгрыш футболки и маски Свиного Рыла, которую он впервые снял публично!  Ну и постарались разогнать печаль после кошмарного старта.   Срочно врубайте, подписывайтесь (а еще на телеграм-канал «Спартак Шоу», чтобы ничего не пропустить) и пишите комменты!  https://youtu.be/_Xl0DRIOIo0  П Старт РПЛ, Станкович, Соболев и «где Барко?» | Спартак Шоу #1 Друзья, мы запускаем Спартак Шоу! В первом выпуске обсуждаем поражение «Спартака» от «Оренбурга» в первом туре РПЛ, Станковича, Соболева, трансферы и инсайды.  Наши ведущие: Макс Никитин – https://t.me/spartakoz Сабина Актерина – https://t.me/akterinatv Антон Милёшин – https://t.me/pigesface  00:00 Первый выпуск Спартак Шоу 00:48 Деанон Свиного рыла! 01:42 Идеи Станковича не сработали. Что дальше? 05:00 Обсуждаем стартовый состав и Соболева 09:39 Почему «Спартак» не подготовился к забросам «Оренбурга»? 13:30 Подходит ли состав под Станковича? 16:30 Яркие цитаты межсезонья 24:51 Как «Спартак» нашёл Станковича? Почему не Слишкович? 32:55 Какие плюсы у нового тренера «Спартака»? 35:53 Позитивный момент в поражении от «Оренбурга» 37:40 Как тренирует Станкович? 40:55 Прогноз от суперкомпьютера 45:10 Молодые футболисты в «Спартаке» 47:35 Трансферы: где Барко? 51:29 Виллиан Жозе и лишний вес. Нужна помощь Артема Реброва 59:15 Какие позиции рассматривает «Спартак» на усиление? 01:00:30 Инсайды! 01:04:00 Покинет ли Соболев «Спартак»?  01:07:47 Вернется ли Промес в «Спартак»? 01:11:11 Прогнозы на август! 01:13:45 Могли прийти, но не пришли 🔗 https://youtu.be/_Xl0DRIOIo0',
#  'Я вроде не садист, но мне так понравилось издеваться над людьми, что я точно буду это дело продолжать 😈😂😂  Ребят, а гляньте пожалуйста моё новое шоу, оставьте отзыв и предложите нововведения. Очень нужна обратная связь.   ШОУ ОЛЕГ ОЛЕГ ШОУ ОЛЕГ ОЛЕГ ШОУ ОЛЕГ ОЛЕГ',
#  'Через 10 дней лечу в Париж на Олимпийские игры! 🙏🏻😍 Почти все буду постить  в Телеге, подписывайтесь: https://t.me/Emma_figuristo4ka   Надеюсь, у меня все получится! 🙏🏻💫  P.S. И кто бы что не говорил, а все равно, по сей день,  каждая федерация и организаторы мероприятий,  прописывая  регалии того или иного спортсмена, всегда начинают с олимпийских достижений! И даже если спортсмен ничего не завоевал, гордо пишут: участник Олимпийских игр! Поэтому, и мы будем гордиться каждым спортсменом, кто доедет, выступит в Париже!!!! ❤️ Вот я на Олимпийских играх не выступала и очень об этом сожалею…  Восполняю тем, что на них работаю, но, это другое)))   📸 Дмитрий Челяпин поймал на футболе 🥰  Прикреплённые ссылки: 🔗 https://t.me/Emma_figuristo4ka',
#  'У моей подруги и коллеги, которой я уступила место уже в нескольких фильмах, но все также любимой и вдохновляющей вышел трек. Не слушаете, если плохое настроение.   https://music.yandex.ru/album/32209395/track/128400484?utm_medium=copy_link  П Ю-ху Anna Glaube слушать онлайн на Яндекс Музыке Anna Glaube • Трек • 2024 🔗 https://music.yandex.ru/album/32209395/track/128400484?utm_medium=copy_link',
#  'https://vk.com/wall-225813819_84  "СРОЧНО НУЖЕН КОФЕ!"',
#  'Как найти смысл жизни в момент, когда кажется, что совсем его нет? Как найти в себе силы двигаться дальше и понять — самое ценное, что есть у тебя — это ты сам!?😓  Ищите ответы в новом выпуске шоу «Открытый прием»: https://youtu.be/qVH4tWY9KWw',
#  'Ходили пьяные на мероприятия? @artemvinokur  (Подкаст ГАДЗИЛЫ с Женей Сидоровым) на ютуб канале',
#  'Таро-прогноз на 23 Июля – Туз Мечей.   🔮 Совет: Меч – это достаточное количество сил для энергичных начинаний,\xa0огромная решимость действовать, начало успешной борьбы, готовность к росту, отрыву от изначального существования. Это ситуация, когда сам человек для себя многое прояснил и знает теперь, что хочет делать дальше. Это показатель силы – физической силы, силы воли, силы, приобретенной положением и умом или в силу обстоятельств.\xa0Триумф личной силы, власти над обстоятельствами. Триумф может относиться к любой стороне жизни: к работе, любви, денежным делам, духу, любым увлекающим занятиям. Этот Туз не столько начало, но и показатель завоеванного, торжества провозглашенных взглядов и принятых решений.   💰 Деньги: Процветание. Принятие однозначных и окончательных решений в этих вопросах. Возможность улучшить качество жизни, приняв вызов.   \U0001fa77 Любовь: В области отношений Туз Мечей символизирует импульсивную первобытную силу, интенсивные «завоевательные» эмоции, крайние чувства, связанные с ситуацией или человеком. Эмоции, которым покровительствует Туз Мечей, способны воспламенить таким огнем, который сожжет все препятствия на пути к цели, попутно причинив немало вреда. Мечи вообще масть холодная, и когда на горизонте в кои-то веки появляется единственная эмоция, то она заполоняет собой всё со свойственной этой масти тотальностью.  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base',
#  'Можно ли прощать побои супругу?  Ответы ищите в новом выпуске шоу «Открытый прием»: https://youtu.be/qVH4tWY9KWw',
#  'comment_show https://t.me/comment_show/8012    Вот он — первый лайв нового сезона. Чемпионат России вернулся! Ждали очень сильно. Прямо очень.  Без раскачки врываемся в старый, местами добрый диалог о первом туре. Банда такая: Шнякин, Генич, Казанский, Арустямян. Стол тоже будет.   Понедельник, не забудь. Велком: youtu.be/g0KbX006Q18',
#  'Сумасшедшая семейка или один новый формат – добро пожаловать за кулисы! Теперь, эксклюзивно на RUTUBE, будут выходить влоги про мою жизнь. Там я расскажу о том, что не попало в фокус СМИ и социальных сетей, покажу себя в естественной среде обитания, и буквальном смысле с двумя детьми на шее)  В первом выпуске вы увидите как прошла наша гендер-пати, кого мы с Артуром ждали – мальчика или девочку, а также как на самом деле дочки отреагировали на новость о беременности.  Переходите скорее на Рутьюб, и пишите в комментариях как вам наше безудержно энергичное семейство (поддержите Артура за участие в этом мероприятии)! Ссылка в шапке профиля ❤️',
#  'https://t.me/s/timzhur/4320  недавно в Лондоне пару свободных часов я потратил не на паб или шоппинг, а на стадионный тур. и ни в коем случае не жалею. потому что это был колоритнейший Крейвен Коттедж.   вы тоже, думаю, не пожалеете, если составите мне компанию. тем более, там разыгрывается футболка.   👉 ССЫЛКА!    Сообщение закреплено',
#  'Сходил в гости к пацанам. Поговорили за деньги🤑 И не только…☺️  https://youtu.be/fc0i_aOaMns  П МИЛЛИОН ОТ ПЕРВОГО КАНАЛА | ДЕНЬГИ ОТ СПОНСОРА | ЗАРПЛАТА НА НТВ-ПЛЮС | ЛУДОМАНИЯ | МУДРАЯ ЖЕНА FoodBand доставит пиццу, роллы, лапшу, курочку, лимонад круглосуточно. Скидка до 25% на все заказы по промокоду ДЕНЬГИ в приложении FoodBand https://bit.ly/35qAaAs или на сайте https://clck.ru/3Bw2gV  Константин Генич - новый гость подкаста "За деньги".  Как завершить футбольную карьеру и найти себя в другом. Как Первый канал предлагал около миллиона рублей в месяц, а Константин отказал.  Как справиться с лудоманией и держать себя в руках. Как буки переманивают амбассадоров. Как встретить ту, которая будет поддерживать тебя во всем.  Вы его слушали во время финала Евро-2024, а вот вам еще 100 минут.   00:00 - Начинаем 00:10 - "Почему Генич лучший?" 04:29 - Про детство Константина 07:29 - Можно и поесть 10:09 - Продолжаем про детство и молодость  18:27 - Образование футболистов. Как Генич расширял свой кругозор 20:45 - Первые деньги 25:12 - Начало футбольной карьеры и увеличение заработков 27:20 - Траты на старте карьеры 30:39 - Длительные загулы 34:05 - Константин Генич - герой-любовник? 36:04 - Дает ли Константин в долг?  39:03 - Глупые вложения денег 45:42 - Первые шаги после завершения футбольной карьеры. Выход из зоны комфорта 52:54 - "Мне повезло, что в какой-то момент я оказался рядом с Васей" 58:40 - Футбольный клуб.  1:02:42 - Всплеск карьеры Константина. 2018 год и что предшествовало ему 1:07:05 - Тот самый репортаж "под градусом" из Бразилии вместе с Черданцевым 1:09:48 - Вернемся в 2018. Как его провел Генич. Увеличение заработка, предложение от Первого канала и обещания, которым не суждено было сбыться 1:17:40 - Ставки и лудомания 1:27:01 - Как Константин относится к рекламе букмекеров, будучи амбассадором одного из них 1:29:38 - Про доходы, гонорары, спонсоров и переманивания в сфере букмекеров 1:34:15 - История знакомства с женой и отношения спустя 15 лет успешного брака 1:39:40 - Завершение 🔗 https://youtu.be/fc0i_aOaMns',
#  'Утро не могло стать горячее, но именно сегодня вышла «Дерзкая готовка» с Оксаной Самойловой – как никогда вовремя 🔥  В начале выпуска специально для моего YouTube-канала Оксана дала эксклюзивный комментарий, в котором в деталях и со спойлерами рассказала о своих эмоциях после участия в своем первом реалити «Выжить в Дубае: Возвращение» 🙈  Коснулись темы отношений с Викторией Боней после съемок, рейтингов, азарта...  А ещё Оксана объяснила, почему зрителям не получится понять юмор звездной команды 🤨  Всё с пылу с жару! Одно из самых насыщенных интервью... Скорее переходите по ссылке, чтобы посмотреть новый выпуск шоу 👏💥  © Ляйсан Утяшева',
#  'Послание от Вселенной на новую неделю 💫  Чтобы принять это послание и воплотить его в жизнь, напишите в комментариях: ПРИНИМАЮ!  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base',
#  'Сегодня исполнилось 87 лет  со дня рождения Эдуарда Стрельцова, возможно, самого талантливого футболиста, который рождался в нашей стране.   4 года назад мы делали о Стрельцове небольшое кино. Там очень мало про историю на даче, которая обернулась для Стрельцова тюрьмой. Гораздо больше - про масштаб таланта и личности Эдуарда.   И еще - про фильм «Стрельцов», который тогда только вышел на экраны и мгновенно подвергся пламенной критике. В этом фильме снялся мой товарищ Денис Казанский. Мы поговорили и с ним, и с режиссером картины Ильей Учителем. А еще - с Юрием Семиным, который играл против Стрельцова. С другом Стрельцова Михаилом Гершковичем. Со Станиславом Гридасовым, подробно изучавшим материалы дела. И с Александром Шмурновым, яростно раскритиковавшим фильм.  https://youtu.be/hrmxQdd7taA?si=EZUuvZsBRzYZ2vRO  П Что мы знаем о Стрельцове? Кем он был для мирового футбола? Каким он показан в фильме "Стрельцов"? Эдуард Стрельцов - возможно, главный талант русского футбола. Уже в 17 он дебютировал за сборную СССР, оформив хет-трик в игре против Швеции. В 18 стал лучшим бомбардиром Чемпионата Советского Союза. А еще спустя год - Олимпийским Чемпионом.  Спустя 2 года, он должен был ехать на Чемпионат Мира в качестве главной звезды советской сборной, но за день до отъезда на турнир был арестован по обвинению в изнасиловании. Какой могла получиться карьера Стрельцова, если бы не 5 лет в тюрьме и 2 года отлучения от футбола? Какие качества позволили Стрельцову, спустя 7 лет, вернуться в футбольный топ и дважды стать лучшим игроком СССР? В чем был феномен популярности Стрельцова? Что такое стрельцовская пятка? И реально ли представить Стрельцова в современном футболе?  Мы поговорили с людьми, которые знали Стрельцова, играли против него или следили за его карьерой. Мы встретились с режиссером фильма "Стрельцов" Ильей Учителем и поговорили с ним о критике сценарных нестыковок и исторических неточностей. Каким был показан в фильме Стрельцов, и похоже ли это на правду? Смог ли Александр Петров передать образ легендарного игрока? Каким увидели фильм те, кто знал Стрельцова и те, кто следил за его карьерой?  Этот фильм - дань памяти легенде советского футбола и его игре.  О Стрельцове говорили: Юрий Семин - играл против Стрельцова Михаил Гершкович - играл и дружил со Стрельцовым Геннадий Орлов - видел игру Стрельцова Александр Шмурнов - рос на рассказах о Стрельцове Илья Учитель - снял фильм о Стрельцове Денис Казанский - сыграл в фильме о Стрельцове Станислав Гридасов - изучал историю Стрельцова  ПС. Большой подкаст Станислава Гридасова, посвященный Эдуарду Стрельцову, можно послушать по ссылке: https://www.youtube.com/watch?v=d3Ho0b0pRng&t=1810s   Мой ingram https://www.ingram.com/mossakovskiy Мой Twitter https://twitter.com/mossakovskiy Мой Telegram канал https://t-do.ru/mossakovskiy  Что мы знаем о Стрельцове? Кем он был для мирового футбола? Каким он показан в фильме "Стрельцов"? https://youtu.be/hrmxQdd7taA 🔗 https://youtu.be/hrmxQdd7taA?si=EZUuvZsBRzYZ2vRO',
#  'МЫ УЖЕ В ЭФИРЕ!   Скорее переходите по ссылочке: https://start.bizon365.ru/room/163462/lenorman1   Не опаздываем ❤️',
#  'УВИДИМСЯ ЧЕРЕЗ ЧАС 🔥   Встречаемся в 12:00 по мск ⚡️⚡️⚡️ по ссылке: https://start.bizon365.ru/room/163462/lenorman1   Все готовы? ❤️ пишите ваши ожидания от урока и курса в целом ⬇️',
#  'Влог с Юга https://youtu.be/ivObhyJL3RE  П Влог с Юга Вашурина, Никитушка и Катеринка сняли свое недельное путешествие на камеру, и вот. что из этого вышло. Приятного просмотра!  Точки отдыха:  - отель Radisson Blu Rostov-on-Don (г.Ростов-на-Дону) Для подписчиков моего канала у нас есть промокод TRIP, который дает скидку 10% на проживание в отеле Radisson Blu Rostov-on-Don  - глемпинг Villey Uley (г.Сочи) Для подписчиков моего канала у нас есть промокод vashourina, который дает скидку 10% на проживание до 29.12.24  - кемпинг "9 километр" (г.Джубга) Для подписчиков моего канала у нас есть скидка 10% на проживание в Сафари-тенте  Соцсети ведущих: ingram.com/vashourina ingram.com/es_zaytseva ingram.com/kulakov_ns  Монтажёра, превью мейкера: ingram.com/frogsoill 🔗 https://youtu.be/ivObhyJL3RE',
#  '1️⃣ Вводный урок «В чём отличие Ленорман от других мантических (предсказательных) систем и от Таро?».  Рад презентовать вам моё первое видео, вышедшее в рамках знакомства с таким потрясающим мантическим инструментом, как Оракул Ленорман ⬇️  🔮 Ссылка на 1 видео-урок марафона 👉🏻 https://youtu.be/nlePFgvgbVk ⠀ Для всех тех, кто жаден до новых знаний, кто всегда стремится узнать чуть больше остальных, кто хочет разобраться с предметом, кому недостаточно «шапочного знакомства», стартовал наш марафон!🚀 ⠀ Итак, в чём же принципиальное отличие Ленорман от Таро? И почему я рекомендую начать своё знакомство с миром мантических инструментов с Оракула Ленорман? ⠀ 1) Ленорман гораздо проще и быстрее усваивается. Но это не значит, что Оракул чем-то хуже Таро. Просто это совершенно разные системы, с разным подходом и полем применения. Ленорман — это универсальная колода, которая отлично подойдёт для ответа на какие-то бытовые вопросы, ответы формата да/нет, диагностику «здесь и сейчас», прогнозирование событий. В отличие от карт Таро, Оракул Ленорман не подойдёт для ответов на вопросы о смысле жизни и о реинкарнационных смыслах. То есть, карты Таро близки к психолого-терапевтическим методам, а Ленорман удобнее в социальных и бытовых вопросах. ⠀ 2) Следующее существенное отличие двух инструментов — работая с Оракулом Ленорман, крайне важно отслеживать то, как именно и в каком порядке расположены карты в раскладе, как взаимодействуют друг с другом рисунки на них (вплоть до того, как и куда смотрят лица персонажей). А ещё в Ленорман мы не трактуем перевёрнутые карты, как это делается в Таро. ⠀ 3) Во многих колодах Ленорман мы можем на поле карты увидеть её игральное значение. Оно НИКОГДА не трактуется, потому что появилось лишь в процессе исторического синтеза. ⠀ Кстати, а вы в курсе, что сама Ленорман никогда не видела Оракула Ленорман, а использовала в своих предсказаниях обычную игральную колоду? На базовом курсе «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» (следующая ступень после марафона), на первом уроке\xa0я рассказываю, как так вышло и почему мы пользуемся другой колодой. И даю ещё много знаний, делюсь секретными фишками и своими собственными ноу-хау. ⠀ 🔮 Ссылка на 1 видео-урок марафона 👉🏻 https://youtu.be/nlePFgvgbVk  🎁🔥 РАСПРОДАЖА КУРСА «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС» В РАССРОЧКУ 👉🏻 http://alexeygrishin.com/lenorman_base  📲 Служба поддержки по всем вопросам, а также, по вопросам записи на бесплатное собеседование на VIP-тариф курса «ОРАКУЛ ЛЕНОРМАН. БАЗОВЫЙ КУРС»❓и оплаты 👉🏻 +7-904-335-85-33 (Telegram, WhatsApp). Прямая ссылка на WA-диалог со Службой поддержки 👉🏻 https://wa.me/79043358533  П БЕСПЛАТНЫЙ КУРС «ЛЕНОРМАН С НУЛЯ». УРОК 1. В ЧЕМ ОТЛИЧИЕ ЛЕНОРМАН ОТ ТАРО? 🔮🔥 🎁 БАЗОВЫЙ КУРС «ОРАКУЛ ЛЕНОРМАН» С 50% СКИДКОЙ 👉🏻 https://alexeygrishin.com/lenorman_base  🎁 ВСЕ СКИДКИ И АКЦИИ 👉🏻 https://taplink.cc/grishin1309 🤫 СЕКРЕТНЫЙ КЛУБ GRISHIN CLUB 👉🏻 http://alexey-grishin.tilda.ws/vip_tg ⚡️ ОФИЦИАЛЬНЫЙ САЙТ 👉🏻 https://alexeygrishin.com ⚡️ TELEGRAM 👉🏻 https://t.me/alexeygrishin ⚡️ YOUTUBE 👉🏻 https://www.youtube.com/c/AlexeyGrishinTAROT ⚡️ VK 👉🏻 https://vk.com/alexgrishin ⚡️ ГРУППА VK 👉🏻 https://vk.com/tarotlenorman ⚡️ OZON 👉🏻 https://ozon.ru/t/jZXa8E2  📲 Служба поддержки по всем информационным и техническим вопросам, а также, по всем вопросам сотрудничества и оплаты 👉🏻 +7-904-335-85-33 (Telegram, WhatsApp). Прямая ссылка на WA-диалог со Службой поддержки 👉🏻 https://wa.me/79043358533 🔗 https://youtu.be/nlePFgvgbVk',
#  '4 серия уже на канале!  Срочно нужно ваше мнение о путешествии.  Смотреть',
#  'Дорогие друзья!  По вашим многочисленным просьбам мы продолжаем исторические кулинарные лекции с [id51547887|Татьяна Цветкова] .   И сегодня тема «Петербургская кухня». Это уникальный гастрономический феномен, возникший в результате слияния двух культур: традиционной русской кухни и изящной французской с некоторыми добавлениями других национальных кулинарных рецептур.   Не пропустите и самого приятного вам просмотра!  https://youtu.be/byxu0Bfu-Jg?si=wJpHM7u496jkH8wh  Прикреплённые ссылки: 🔗 https://youtu.be/byxu0Bfu-Jg?si=wJpHM7u496jkH8wh',
#  'Почему люди познают любовь через боль?!  Ответы ищите в новом выпуске шоу «Открытый прием»: https://youtu.be/qVH4tWY9KWw',
#  'Существует миф о том, что «уколы красоты» вызывают привыкание со стороны кожи. На этот счет было проведено множество исследований, которые доказали, что препараты лишь выполняют свою функцию, а привыкание возникает лишь на психическом уровне.   Тут срабатывает психосоматика, пациент начинает внушать себе, что красоту можно спасти только с помощью постоянных инъекций.  Это называется дисморфофобией, расстройством личности, при котором человек чрезмерно обеспокоен и занят незначительным дефектом или особенностью своего тела. Согласно статистическим данным, от 1,5 до 2,9% людей страдают этим расстройством.  Что заставляет миллионы женщин ложиться под нож и какие триггеры тут срабатывают смотрите в новом выпуске шоу «Открытый прием».  Переходите по ссылке для просмотра: https://youtu.be/qVH4tWY9KWw',
#  '😬 СТРАХ ПЕРЕД СВЕКРОВЬЮ – НЕ❌ НОРМА! УЧИМСЯ ПОНИМАТЬ МАТЬ МУЖА.  ⚡️ Премьера новой, 3 серии подкаста «Лунные сутки»🌛 с Алексеем Гришиным в качестве ведущего!👌🏻  «Лунные сутки» – это уникальный подкаст, в котором можно и поржать🤣 и «нырнуть на глубину» на самой настоящей Таро-сессии🔮  🌛 3 СЕРИЯ ПОДКАСТА «ЛУННЫЕ СУТКИ» С АЛЕКСЕЕМ ГРИШИНЫМ 👉🏻 https://youtu.be/0VFeWbOgpc8',
#  'SKZ продлили контракт😍 А я ролик выложил,посмотри пошли пожалуйста  https://youtu.be/KzQGX66p6to?si=fAuzKxFJq-i21GRI  П BOOKLOG: топ 3 книги этой недели Вы просили очень давно показать вам топ моих книг.Рубрика BOOKLOG созданна специально для того,чтобы поделится с вами моими любимыми книгами 🔗 https://youtu.be/KzQGX66p6to?si=fAuzKxFJq-i21GRI',
#  'МУЖЧИНА ПО СУДЬБЕ И ПО… ЗВЕЗДЕ 🫢💫  Полная версия уже на моем YouTube-канале по ссылке 👉🏻 https://youtu.be/o6TOvKa-gSg  🎁 Скидка на Розовый кварц 💎💕👉🏻 https://ozon.ru/t/9AgdG77',
#  'Опубликован комментарий к записи: https://vk.com/wall-161938332_7842  Ссылочка https://youtu.be/ra1wHrMyP3U?si=WHU3thQbipiN-vs8',
#  '⚡️🔮 Премьера! 22 серия 2 сезона ток-шоу «Кадони Шоу» под названием «Ставки сделаны» на ТВ-3 с участием Алексея Гришина 👉🏻 https://rutube.ru/video/9e77f7f17432d03550091c0b9b6660fe/',
#  '⚡️🔮 Премьера! 22 серия 2 сезона ток-шоу «Кадони Шоу» под названием «Ставки сделаны» на ТВ-3 с участием Алексея Гришина 👉🏻 https://rutube.ru/video/9e77f7f17432d03550091c0b9b6660fe/',
#  '⚡️🔮 Премьера! 22 серия 2 сезона ток-шоу «Кадони Шоу» под названием «Ставки сделаны» на ТВ-3 с участием Алексея Гришина 👉🏻 https://rutube.ru/video/9e77f7f17432d03550091c0b9b6660fe/  Прикреплённые ссылки: 🔗 https://rutube.ru/video/9e77f7f17432d03550091c0b9b6660fe/',
#  'Лев Толстой говорил — «Не красота вызывает любовь, а любовь заставляет нас видеть красоту»   И знаете, не каждый это понимает, миллионы женщин, которые не принимают себя и свою естественную притягательность.  Кто-то боится старости, кому-то просто не нравится в себе что-то, а другие же, думая, что изменив внешность до неузнаваемости, смогут поменяться изнутри, а может и поменять свою жизнь. Но все это иллюзия, потому что от себя не убежишь, какой бы формы не был у тебя нос, какую цифру показывает паспорт. Вся эта смена внешности, чаще всего, не всегда, приводит к обрывает естественную красоту, стирает обаяние, делая всех одинаковыми, бездушными и безликими.   Скажите, есть ли то, что вы бы хотели в себе изменить, поделитесь, какой от этого ждете выхлоп?  Я очень надеюсь, что новый выпуск шоу «Открытый прием» даст ответ на этот вопрос: https://youtu.be/qVH4tWY9KWw',
#  'elenalande_chef https://t.me/elenalande_chef/1151    ❤️ Друзья, если вдруг Вы пропустили наш с Андреем Атласом шортс о том, как вкусно приготовить рыбу:  https://youtube.com/shorts/cGViKRO9E6c?si=-NMERAG_-sYTPQbb  П Домашний рестик. Снова экономим и отбираем чью-то прибыль) «Атлас рыб красных» #shorts Домашний рестик. Снова экономим и отбираем чью-то прибыль)«Атлас рыб красных»ГравлаксВариант 1.1.Свекла уже кем-то отваренная и даже почищенная 2шт2.Рыба кра... 🔗 https://youtube.com/shorts/cGViKRO9E6c?si=-NMERAG_-sYTPQbb',
#  'Скоро на моем ютубчике,выйдет рубрика «BOOKLOG» Вы просили рассказать вам о книгах которые я читаю,а я решил посвятить этому целую рубрику💜  https://youtube.com/@kagramana?si=fdDMgV5eq_GbRcII',
#  'РИТУАЛ СО СВИДАНИЯМИ НА НОВЫЕ ОТНОШЕНИЯ 🔮💞  Полная версия уже на моем YouTube-канале по ссылке 👉🏻 https://youtu.be/o6TOvKa-gSg  🎁 Скидка на Розовый кварц 💎💕👉🏻 https://ozon.ru/t/9AgdG77',
#  'Такой бодрой раздачей я начинал свой стрим на NL5000$ в рамках челленджа «Амбассадоры vs Хайроллеры» в день старта. А сегодня с 18:00 сражаются Дима Шахов и Дамир Жугралин!!!   Эти лютые супердорогие для нас кэш-схватки можно смотреть в прямом эфире по ссылкам:  https://youtube.com/live/VHggTWt1nrQ?feature=share  https://twitch.tv/pokerok_official/home  https://kick.com/pokerok-streams  Напомню, что каждый из нас пытается преумножить призовой фонд турнира «Кубок Котэ», который состоится 6-го июля. Половина стека после 3х часов на NL5K пойдет в награду за выбивание амбассадора на «Кубке Котэ». Зарегаться туда можно в том числе и через PokerBitOk, а эту валюту можно намайнить, если регулярно смотреть наши стримы по ссылкам выше.  Все подробности в ТГ-канале ПокероК: https://t.me/pokerok_official',
#  'РИТУАЛ СО СВИДАНИЯМИ НА НОВЫЕ ОТНОШЕНИЯ 🔮💞  Полная версия уже на моем YouTube-канале по ссылке 👉🏻 https://youtu.be/o6TOvKa-gSg  🎁 Скидка на Розовый кварц 💎💕👉🏻 https://ozon.ru/t/9AgdG77',
#  'Рубрика «РАЗБОРЫ» – каждую среду в GRISHIN CLUB!  Мои Волшебные💫, я возобновляю долгожданную для многих учеников и слушателей рубрику с разбором практических кейсов с Раскладами.  ✅ Каждую среду в GRISHIN CLUB мы будем разбирать с вами Расклад (Таро/Ленорман/Руны и т.п.) из моей личной практики. Также, мы будем разбирать сложные комбинации карт, и всё, о чём НЕ❌ напишут в книжках.  ✅ В среду утром я буду давать вам практический кейс, который поможет вам углубить ваши трактовки, умение преломить значения карт или рун под запрос, а также, развить необходимые для практика образное мышление и гибкость ума.  ✅ После разбора кейса в комментариях, в GRISHIN CLUB, я дам обратную связь по трактовке в течении пары дней. Без двоек, троек, четвёрок и пятёрок. Без осуждений. Только с полезными советами, помощью и рекомендациями!❤️ Чтобы каждый из вас мог стать лучше и окрепнуть в практике.  ✅ А так же, участники закрытого канала GRISHIN CLUB, раз в неделю, в специальном окошке, могут размещать свои Расклады для совместных трактовок и обсуждений. Условия: фотография расклада, четко сформулированный запрос, любой расклад на 3 карты или любой другой Расклад до пяти позиций.  Вступить в секретный VIP TG-канал «GRISHIN CLUB»: https://t.me/grishin_club_vendor_bot  Инструкция к боту-продавцу «GRISHIN CLUB BOT»: https://docs.google.com/document/d/1jAGqqZCamGmt9oYBGY3W9Dz4Fd2aSJFleWRrdGFRzeU/edit?usp=sharing  До встречи в моем секретном Клубе!🤫  🎁 Бесплатный марафон «Оракул Ленорман за 3 секунды» 👉🏻 https://alexeygrishin.com/orakul-lenorman-3sec',
#  'РИТУАЛ СО СВИДАНИЯМИ НА НОВЫЕ ОТНОШЕНИЯ 🔮💞  Полная версия уже на моем YouTube-канале. Ссылка на канал 👉🏻 https://www.youtube.com/c/AlexeyGrishinTAROT  Перейти по ссылке можно В ШАПКЕ ПРОФИЛЯ👆🏻 или вбить вручную в поисковике на YouTube - AlexeyGrishinTAROT',
#  'Ребята!  Я все еще в отпуске, но вышло шоу «Звездный дурак», посмотрите его, пожалуйста)   Это одно из любимых и смешных шоу, в которые я ходила)  Потрясающий состав! Было весело) У меня болели щеки)))  https://vk.cc/cyqvob',
#  'https://t.me/s/mossakovskiy/3092  Итоги Евро с маэстро Елагиным! Врывайтесь!  Осторожно! В выпуске много Гарета Саутгейта и сборной Англии!  https://youtu.be/NJD6k9pYB8U?si=N3OTilov5cpG0aWu    Сообщение закреплено',
#  'Итоги Евро с маэстро Елагиным! Врывайтесь!  Осторожно! В выпуске много Гарета Саутгейта и сборной Англии!  https://youtu.be/NJD6k9pYB8U?si=N3OTilov5cpG0aWu  П Александр ЕЛАГИН // ИТОГИ ЕВРО-2024 Это подкаст "Что Делать?"  За бонусом, яркими эмоциями и азартом игры - переходи по ссылке! https://t.me/mossXec24/3  Наш гость - Александр Елагин! Подводим итоги Евро! Осторожно! В видео много Гарета Саутгейта и сборной Англии!  #Евро2024  #Елагин #Мосс  Пишите в комментариях ваш вариант финальной пары и итоговый счет! Первый угадавший получит в подарок талисмана Евро!  Подкаст сделан в сотворчестве и соавторстве с Александром ФРАНЦЕВЫМ.  Спасибо пабу "ТРИ ЗЛЫЕ ЖЕНЫ" (Мичуринский пр, 22) за гостеприимство. Если вы в Москве и планируете выпить пива - вам туда! Спасибо агентству «СИМПЛ СПОРТ» за поддержку и дружескую помощь.  Мой Telegram канал https://t.me/mossakovskiy Мой ingram https://www.ingram.com/mossakovskiy  00:00 Начало 00:28 Наш гость - Александр Елагин 02:50 Футбол победил антифутбол? Как де ла Фуэнте изменил сборную Испании? 08:08 Почему англичане в сборной менее ярко, чем в клубах?  Саутгейт  12:05 Гарет Саутгейт - талантливый убийца футбола или просто слабый тренер? Команда Саутгейта могла стать великой? 21:00 Евро-2024 - чемпионат уставших звезд? 64 матча Ямаля за сезон в 16 лет - выдержит ли он? 25:40 О грамотном партнерстве 26:32 Кто лучший тренер турнира? Лучший игрок? В чем магия Родри? 28:08 Почему Елагин считает, что турнир получился средним? Как изменилась сборная Англии?  29:57 Молодые таланты со скамейки сборной Англии. Кто из них станет настоящей звездой? 32:35 Оправдывает ли результат блеклую игру? 36:00 Кого будет не хватать из тех, кто заканчивает? Есть ли сейчас такие игроки, как Кроос и Модрич? 39:42 Должен ли Роналду остаться в сборной? Поможет Криштиану Португалии на ЧМ или потопит ее? 43:55 Евро-24 - турнир без ярких звезд. Командное становится выше личного? Родри - единственная суперзвезда. 46:13 Феномен маленьких сборных. Раскрепощенные Австрия, Турция, Грузия, Швейцария 52:37 Станет ли эта сборная Испании командой-династией? 58:05 Благодарочки 🔗 https://youtu.be/NJD6k9pYB8U?si=N3OTilov5cpG0aWu',
#  'buz_haus https://t.me/buz_haus/3411    «Легенда Оля Бузова. Нам до нее всем расти и расти», — Алексей Столяров в интервью YouTube-каналу Dr. Tochiev https://youtube.com/watch?v=-xCXUEQuMus&si=j1_eHbJvSz1DBb2W  #ОльгаБузова #новостизвезд #будниартиста',
#  'https://t.me/izvestnose/12382 Коллеги из СЭ, где моя цитата, что сборную Англии должен возглавить Александр Мостовой, который научит англичан играть в футбол??? Какого хрена????😜  П ⚡️ Как стало известно «СЭ» Дмитрий Губерниев — об уходе Саутгейта из сборной Англии: «Им нужен тренер, который научит их играть в футбол»  Глобально пофиг, конечно, ушел и хрен с ним. Но если серьезно, они же задачу не выполнили. Играют лучше с ним, если с точки зрения результата смотреть, но что-то постоянно идет не так. С таким составом англичане справедливо надеялись на что-то большее, чем финал. Поэтому Англии нужен тренер, который научит их играть в футбол. Понимаете, Саутгейт добился на европейской арене больше, чем Валерий Лобановский, по результату. Они серебряные медалисты чемпионата Европы. Это достижение? Безусловно, да. Поэтому Саутгейт — тренер хороший, у него свое видение. С мастеровитой клубной командой этот футбол может принести успех. Ну, если, конечно, он не будет записывать музыкальный альбом с Александрой Трусовой, тогда его спортивные дороги уведут совсем в другое место  Больше новостей на @izvestnose 🔗 https://t.me/izvestnose/12382',
#  'Друзья! Наконец-то это случилось, я выложила стендап на ютуб! Надеюсь вам понравится) Подписывайтесь, Лайкайте, Комментируйте!  Вот ссылка https://m.youtube.com/watch?v=OH62vfb_VzU',
#  'sovsport https://t.me/sovsport/19146    🗣️ «Спартак» бездарно профукал Глушенкова». Колумнист «Совспорта» Дмитрий Губерниев – о тенденциях Евро и РПЛ.  🇪🇸 «А нам-то какая польза? Футбол – игра логичная, тем не менее победила Игра, именно с большой буквы. Это главное, поэтому я очень рад за испанцев и за вундеркинда Ямаля. Люди доказывают, что всё-таки в футбол надо играть, а не мучиться, хотя повторю, что всё-таки я думал, что выиграет Англия».  🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f «Кейн менее великим не стал. Много было разговоров о Гарри Кейне. Ведь он проиграл шесть финалов. А после перехода в «Баварию» и там не получилось выиграть командный трофей. Но давайте констатируем факт – менее великим-то он от этого не стал. Есть люди, которым фатально не везёт с точки зрения тех или иных титулов, но футболист же он классный».  🌊 «Глушенков сразу пришёлся ко двору. Игрок умный, тонкий. Это прочувствовали сразу сильнейшие футболисты «Зенита». И, конечно, в очередной раз вспоминается, как его бездарно профукал московский «Спартак» в своё время. Так не уметь разглядеть талант – надо было умудриться».  💪 «Галактионову нужно перестать быть плакучей ивой. Галактионову нужно работать и держать удар. С моей точки зрения, а не рассказывать где и что. Надо идти работать».  👏 «Снимаю все имеющиеся шляпы. Так рыдать на скамейке после замены, когда у тебя опухла нога и в бутсу уже не влезает, может настоящий боец, а главное – спортсмен с большой буквы».  🙏 «Не обращайте внимания на жужжащих ос. Я по-прежнему хочу сказать, что я буду следить так или иначе за Олимпиадой, желаю всячески удачи тем людям, которые туда поедут, и очень надеюсь, что мы с наградами вернёмся даже в таком малом составе. Эти люди – они большие спортсмены, они большие молодцы, им нужна наша поддержка, и те, кто любит нашу страну по-настоящему, кто верит в Россию, в спорт, они этих людей будут поддерживать. Мы этих людей поддержим».  Колонку Дмитрия читайте здесь.  👍 подписывайтесь на @sovsport',
#  'Ребята, квантовая психология ждет ваших отзывов, комментариев, лайков и брызгов иронии☺️  https://youtu.be/_CQsO8agowc',
#  'В гостях 1-11  мастодонт отечественного блогинга - яркая и классная Полина Трубенкова❤️  Ссылка👇 https://vk.cc/cyqOVO',
#  'Йоу! Это случилось)) Теперь я есть на ютуб!) В шапке профиля ссылка на мой стендап☺️  Заходите, смотрите, смейтесь! И лайкайте и комментируйте!) это обязательно! \U0001fa77 Спасибо за организацию съемки @standup_msk  \U0001fa77 Спасибо съемку команде @standup_view  И отдельное спасибо за монтаж @anna__protokovilo ❤️',
#  'Недовольство собой и собственной внешностью отравляет жизнь миллионов девушек по всему миру. И иногда эти комплексы заставляют решиться на отчаянный шаг – лечь под нож пластического хирурга.   Героиня нового выпуска шоу «Открытый прием» Екатерина стала жертвой пластического хирурга. Шокирующие детали операции поразили сотни тысяч человек по всей России, но виновник трагедии – пластический хирург остался безнаказанным. Девушка пришла к нам на шоу, чтобы рассказать свою историю и восстановить справедливость.   Что заставляет нас делать пластические операции и как принять себя? Вместе со специалистом по телесно - ориентированной терапии Алексеем Большаковым мы поможем разобраться героине в причинах недовольства собой.  Полный выпуск по ссылке: https://youtu.be/qVH4tWY9KWw',
#  'Ребят, вышел новый выпуск моей программы «открытый прием». Хочу, чтобы вы увидели историю девушки, которая нарвалась не на профессионального врача, а на мясника. Как психологически выбраться из такой сложной ситуации, где тебя не только физически изуродовали, но и морально. Смотрите на моем канале',
#  'смотрим новый влог господа!  ура!  тока пишите коменты там под видосом, я же стараюсь снимаю оч хочется обратной связи   новый влог',
#  'Выдающийся, титанический, монументальный труд по разбору трилогии "Матрицы". Предположу, что такой работы по анализу кинематографической единицы (окей, тринити тройки) российский интернет еще не знал. Я серьезно.  На моем любимом ютуб-киноканале ЧБУ вышло пышное видео, в котором... Ну, я не знаю, как это описать, ребят. Погружение в самые недра. Сотни-сотни-сотни отсылок к мировой литературе, духовным трактатам, символам, музыке, интервью, мнениям, картинам, фильмам, текстам, образам, мультипликации, оригинальным озвучке и сценариям. Практически покадровое исследование. Местами буквально по нотам. Впечатляющее, почти нездоровое внимание к деталям:)   Это грандиозная работа. Я немного шокирован даже. Временами огромный ролик превращается в аттракцион, который приближает тебя к пониманию замыслов семейки Вачовски и тут же отталкивает.   Фундаментальный разбор. С немного обескураживающей, но оттого еще более прекрасной концовкой. Все равно что посмотреть новую серию "Матрицы". Благо хрон такой же:)  Запаситесь временем. Оно того стоит, приятного просмотра: https://youtu.be/nKoxZLF_ih4?si=SvbJ3qMT9CCW84lX  @shhhnyakin  П Нео – Бог Boosty: https://boosty.to/the46y  Полная версия видео на моём Бусти.  Telegram: https://t.me/the46y ingram: https://www.ingram.com/the46y/ VK: https://vk.com/nerdfacegroup  Основные треки из видео:  https://www.youtube.com/F0x3r_Fennec https://www.youtube.com/4lienetic https://www.youtube.com/VenusTheory https://www.youtube.com/Kupla  Полный список ссылок и мелодий: https://docs.google.com/document/d/1k-CczI5BOI1KAkr3M0LMmObJWfi_uXCNkX7dTMBCs4s/edit?usp=sharing  00:00 0.Вступление 00:53 1.Платон 03:50 2.Декарт 05:53 3.Бодрийяр 15:22 4.Христианство 31:19 5.Индуизм и буддизм 42:41 6.Буддизм 51:30 7.Индуизм 1:00:31 8.Облачный атлас 1:03:36 9.Мифология 1:07:59 10.Эволюционная психология 1:32:36 11.Душа 1:40:29 12.Призрак в доспехах 1:48:48 13.Алиса в Стране чудес -:--:--       14.Программы изгои (в версии для Boosty) 1:52:05 15.Дуализм, поп-культура, отсылки Вачовски -:--:--       16.Теории (в версии для Boosty) 1:58:38 17.Что такое Матрица? 🔗 https://youtu.be/nKoxZLF_ih4?si=SvbJ3qMT9CCW84lX',
#  'Я и два самых красивых моих родственника сняли для вас новые «Позавчерашние Новости»',
#  'кто вчера не успел,можете посмотреть на RUTUBE🤍🫂  там есть очень смешные моменты😂 можете комментарии там ещё оставить ХОРОШИЕ🥹❤️',
#  'community_show https://t.me/community_show/1301    НОВЫЙ ВЫПУСК ШОУ "ТЫ КТО ТАКОЙ?"🔥  У нас новая студия, новый антураж, но всё те же правила. Ребятам нужно узнать личную информацию о госте, задавая только наводящие вопросы. Если они не справляются - гость получает деньги. Сегодня угадываем информацию про Ивана Абрамова и девушку с анкетой №14. В студии Расул Чабдаров , Павел Дедищев и Витя Алексеев. Ведущий - Гурам Амарян. Приятного просмотра!👇  https://vk.com/video-218471730_456239546  П Ты кто такой #5 Абрамов/Амарян/Дедищев/Чабдаров/Алексеев/Анкета#14 Шоу, в котором комики угадывают личную информацию о госте, задавая при этом только наводящие вопросы. За каждый неправильно угаданный факт, гость забирает реальные деньги. Эксклюзивно в VK Видео. 🔗 https://vk.com/video-218471730_456239546',
#  'community_show https://t.me/community_show/1301    НОВЫЙ ВЫПУСК ШОУ "ТЫ КТО ТАКОЙ?"🔥  У нас новая студия, новый антураж, но всё те же правила. Ребятам нужно узнать личную информацию о госте, задавая только наводящие вопросы. Если они не справляются - гость получает деньги. Сегодня угадываем информацию про Ивана Абрамова и девушку с анкетой №14. В студии Расул Чабдаров , Павел Дедищев и Витя Алексеев. Ведущий - Гурам Амарян. Приятного просмотра!👇  https://vk.com/video-218471730_456239546  П Ты кто такой #5 Абрамов/Амарян/Дедищев/Чабдаров/Алексеев/Анкета#14 Шоу, в котором комики угадывают личную информацию о госте, задавая при этом только наводящие вопросы. За каждый неправильно угаданный факт, гость забирает реальные деньги. Эксклюзивно в VK Видео. 🔗 https://vk.com/video-218471730_456239546',
#  'community_show https://t.me/community_show/1301    НОВЫЙ ВЫПУСК ШОУ "ТЫ КТО ТАКОЙ?"🔥  У нас новая студия, новый антураж, но всё те же правила. Ребятам нужно узнать личную информацию о госте, задавая только наводящие вопросы. Если они не справляются - гость получает деньги. Сегодня угадываем информацию про Ивана Абрамова и девушку с анкетой №14. В студии Расул Чабдаров , Павел Дедищев и Витя Алексеев. Ведущий - Гурам Амарян. Приятного просмотра!👇  https://vk.com/video-218471730_456239546  П Ты кто такой #5 Абрамов/Амарян/Дедищев/Чабдаров/Алексеев/Анкета#14 Шоу, в котором комики угадывают личную информацию о госте, задавая при этом только наводящие вопросы. За каждый неправильно угаданный факт, гость забирает реальные деньги. Эксклюзивно в VK Видео. 🔗 https://vk.com/video-218471730_456239546',
#  'Вчера у блестящего Ильи Трифанова был УКРАДЕН телеграм канал «Коллега Трифанов»! И вот сообщение от Трифанова!!! Сейчас украденный канал доступен по ссылке:  https://t.me/+TjsyGumcmgs4ZWRi  Мошенники пытаются развести людей на деньги.  Прекратить это и вернуть канал можно только если на него массово пожалуется много людей.  Прошу вас зайти и кинуть жалобу на канал, сославшись на мошенничество!!!  Заранее огромное спасибо!!!',
#  'По итогам голосования гибкого супергероя зовут Понтий Пилатес. Хотя в душе он все равно Стас))  А я вот куда ходила. Если кайф, посмотрите!   https://vk.com/video-214484275_456239954?access_key=94272e0e98f978db36  П АРГУМЕНТЫ #путешественник: Еременко, Аранова, Ни, Швецов, Якушев. Аргументы — спин-офф шоу «Факты» эксклюзивно в VK Видео. Ведущие — Илья Швецов, Александр Якушев. Гости - Саша Ни, Лиза Варвара Аранова, Лев Еременко 🔗 https://vk.com/video-214484275_456239954?access_key=94272e0e98f978db36',
#  'Девочки, от души рекомендую канал про отношения. Его ведёт мужчина в формате без лица — поэтому пишет жестко и честно.   Это как подслушать мужской разговор о женщинах за бутылкой виски. Услышите то, о чем не скажет ни один мужик глядя в глаза. Почитайте: москоутиндер',
# ...
#  'https://youtu.be/OgmwI4j5vaE?si=7Tz4H2Twg_fX5CUh  П БОЛЬШОЕ ШОУ. НОВОГОДНИЙ СЕЗОН. РЕАЛЬНЫЙ ТИЗЕР Смотрите 31 декабря каждый час с 14:00 только в VK Видео https://vk.com/azamatmusagaliev 🔗 https://youtu.be/OgmwI4j5vaE?si=7Tz4H2Twg_fX5CUh',
#  'torpedomoscow_fc https://t.me/torpedomoscow_fc/6286    Заглянули сегодня в квартиру Деда 🎅🏼 Мороза и узнали, кто ему пишет письма и какие желания просит исполнить…   #Наш100йГодНачинается уже послезавтра!  П ФК «Торпедо Москва»: наш 1️⃣0️⃣0️⃣🖤-й год начинается...! Попали в квартиру Деда Мороза 30 декабря, когда он как раз читал письма от торпедовцев. Кто написал и что попросил — смотрите в этом новогоднем видео! 🔗 https://youtu.be/bMtZ7H8xi28?si=pkHILxKyqiI_Eb5h',
#  'Это тизер на 40 минут  Вечером эфир на 7 часов   https://youtu.be/HdOPRSEcZDQ?si=VbGS1DpqgbJkUE8z  П Новогоднее заСТВОЛье 2024 Лучшие моменты (Cream Soda, Николаев, Saluki, Бьянка, Михеева, Кассета) Полную версию Новогоднего заСТВОЛья смотрите 31 декабря в 21:00 (мск) на канале STVOL TV https://www.youtube.com/@stvoltelevision  Платите с помощью Яндекс Пэй, скачивайте приложение и\xa0\xa0получайте дополнительный кэшбэк баллами Плюса. https://clck.ru/37J2E9  Управляйте светом и другими приборами голосом или по расписанию. Умный дом с Яндексом проще и дешевле, чем кажется. Попробуйте: https://ya.cc/m/nqZ5mLL  Дорогие зрители Чикен Карри, было приятно прочитать ваши поздравления родным, близким и коллегам. Многие были довольно личные. Спасибо вам за доверие)  В нашем телеграм-канале мы выложим ещё несколько зачитанных поздравлений https://t.me/chickencurryshow Обнимаем! С Новым годом!  Таймкоды:  0:00 Дан Балан и Миногарова организуют бал 2:18 THE DAWLESS, КАССЕТА - KINO 3:59 Смотрите STVOL TV 31 декабря! 5:05 Поздравления с экрана 6:32 BIICLA & POLOVINKA - МНЕ НРАВИТСЯ 8:20 Я тя хрююю 9:27 Репортаж Аллы Михеевой 12:03 Хороший папа 13:04 БЬЯНКА - БЫЛИ ТАНЦЫ 14:55 Маша Миногарова про волшебство 16:28 TURBOSH, SLOWKICK, N96 - ПИВО (ALBLAK 52) 18:23 Брат говнюк 19:02 СТЕРЕО ШИРИНА - ТОРОПЫГА 20:37 Предложение руки и сердца 21:52 ИЛЬЯ СОБОЛЕВ, КОМЕДИАНТ 23:50 Поздравление уродам и друзьям 24:27 АКУЛА - КИСЛОТНЫЙ ДИДЖЕЙ 26:03 Эщкере! 27:13 CREAM SODA - VIBY 29:19 Рыба-у*ба 30:23 ВОРОВАЙКИ - ХОП, МУСОРОК 34:10 Пинок под зад 35:04 SALUKI - ОГНЕЙ 38:05 Ты не так много зарабатываешь 39:14 ИГОРЬ НИКОЛАЕВ - ВЫПЬЕМ ЗА ЛЮБОВЬ 🔗 https://youtu.be/HdOPRSEcZDQ?si=VbGS1DpqgbJkUE8z',
#  'А это вам подарочек   https://vk.com/video-110135406_456242810  П Большое шоу 7 сезон. Первая серия. Покупайте выгодно на Мегамаркете — https://clck.ru/37LdaE Также используйте промокод БОЛЬШОЕШОУ и получите дополнительную скидку 1 000 руб при первом заказе от 3 000 руб! Правила использования промокода: https://clck.ru/37Ldex Erid: 2VtzqwjmbaU Erid: 2VtzqwRjdpQ Erid: 2VtzqvyADkg В “Большом шоу”.. 🔗 https://vk.com/video-110135406_456242810?utm_source=TG&utm_medium=post&utm_term=mqp_bigshow&utm_content=110135406_456242810&utm_campaign=VK_video',
#  '🎄Ну что?! Погнали!  ПЕРВАЯ серия СЕДЬМОГО сезона БОЛЬШОГО ШОУ! 🎉 https://vk.com/wall-110135406_121765  П Азамат Мусагалиев 🎄НОВОГОДНЕЕ БОЛЬШОЕ ШОУ!🥳ПЕРВАЯ СЕРИЯ!🔥  Ну что, всех с неумолимо наступающим Новым годом! Мы начинаем наш безумный марафон смеха и веселья! Топовые комики, секретный гость и впереди ещё целых пять выпусков! Новые серии каждый час! ФИНАЛ в 19:00 по Москве!🔥Эксклюзивно в VK Видео. Приятного просмотра!👇 🔗 https://vk.com/wall-110135406_121765',
#  '🎄Продолжаем! ВТОРАЯ серия СЕДЬМОГО сезона БОЛЬШОГО ШОУ! 🎉 https://vk.com/wall-110135406_121923  П Азамат Мусагалиев 🎄НОВОГОДНЕЕ БОЛЬШОЕ ШОУ!🥳ВТОРАЯ СЕРИЯ!🔥    НОВЫЙ ГОД НАЧАЛ СВОЙ ПУТЬ ПО СТРАНЕ! КАМЧАТКА, ЧУКОТКА С НАСТУПИВШИМ! А мы продолжаем свой марафон "Большого шоу"! ХАРЛАМОВ и новые серии каждый час! ФИНАЛ в 19:00 по Москве!🔥Эксклюзивно в VK Видео. Приятного просмотра!👇 🔗 https://vk.com/wall-110135406_121923',
#  '🎄ТРЕТЬЯ серия СЕДЬМОГО сезона БОЛЬШОГО ШОУ!!! 🎁 https://vk.com/wall-110135406_122011  П Азамат Мусагалиев 🎄НОВОГОДНЕЕ БОЛЬШОЕ ШОУ!🥳ТРЕТЬЯ СЕРИЯ!🔥  ВОСТОЧНАЯ ЯКУТИЯ, СЕВЕРНЫЕ КУРИЛЫ С НОВЫМ ГОДОМ! Кто ещё только готовится встречать и рубит салатики - не забудьте купить горошек! Марафон "Большого Шоу" продолжается! Новые серии каждый час! ФИНАЛ в 19:00 по Москве!🔥Эксклюзивно в VK Видео. Приятного просмотра!👇 🔗 https://vk.com/wall-110135406_122011',
#  '🎄ЧЕТВЁРТАЯ серия СЕДЬМОГО сезона БОЛЬШОГО ШОУ!!!  https://vk.com/video-110135406_456242813  П Большое шоу 7 сезон. Четвёртая серия. Покупайте выгодно на Мегамаркете — в декабре действует повышенный кешбэк до 80% бонусами - https://clck.ru/37KkT5 Также используйте промокод БОЛЬШОЕШОУ и получите дополнительную скидку 1 000 рублей при первом заказе от 3 000 рублей! Правила использования промокода: https://clck.ru/37KkTv Erid: 2Vtzqx2Grc4.. 🔗 https://vk.com/video-110135406_456242813',
#  '🎄ПЯТАЯ серия СЕДЬМОГО сезона БОЛЬШОГО ШОУ!!!  https://vk.com/video-110135406_456242814  П Большое шоу 7 сезон. Пятая серия. Покупайте выгодно на Мегамаркете — в декабре действует повышенный кешбэк до 80% бонусами - https://clck.ru/37KkVT Также используйте промокод БОЛЬШОЕШОУ и получите дополнительную скидку 1 000 рублей при первом заказе от 3 000 рублей! Правила использования промокода: https://clck.ru/37KkX4 Erid: 2Vtzqvu5R6U.. 🔗 https://vk.com/video-110135406_456242814',
#  '🎄ШЕСТАЯ серия СЕДЬМОГО сезона БОЛЬШОГО ШОУ!!! ФИНАЛ! 💥💥💥 https://vk.com/video-110135406_456242816  П Большое шоу 7 сезон. Шестая серия. Финал. Покупайте выгодно на Мегамаркете — https://clck.ru/37Ldgh Также используйте промокод БОЛЬШОЕШОУ и получите дополнительную скидку 1 000 руб при первом заказе от 3 000 руб! Правила использования промокода: https://clck.ru/37Ldhv Erid: 2Vtzqv6siaY Erid: 2VtzqwQPMUG В “Большом шоу” главное требование.. 🔗 https://vk.com/video-110135406_456242816',
#  'Смотрите, чтобы в этом канале появились истории, нам с вами надо собрать сколько-то там голосов. Если кайф, проголосуйте, и у меня тут появятся истории☺️ вам несложно, мне приятно🌸  https://t.me/irinamyagkov?boost  П MYAGKOVA IRINA Проголосуйте за канал, чтобы он смог публиковать истории. 🔗 https://t.me/irinamyagkov?boost',
#  '‼️Ещё одну успели выпустить…  https://youtu.be/A41ml9f4yxc?si=NMkZfcdejdmS3ZDn  П Судейская КХЛ! Заключительный в 2023 году выпуск «Судейской КХЛ». Все моменты в этом выпуске были предложены нашими зрителями!  Ведущие: Владимир Гучек, Алексей Анисимов и Леонид Вайсфельд ________________ Смотри все трансляции КХЛ - https://bit.ly/3fKrQ4n Качай приложение КХЛ для iOS: https://goo.gl/asVY5u Качай приложение КХЛ для Android: https://goo.gl/CifAyU  #КХЛ #Судейская #Анисимов #Вайсфельд #Гучек 🔗 https://youtu.be/A41ml9f4yxc?si=NMkZfcdejdmS3ZDn',
#  'Разговорное шоу о жизни в  эмиграции. Руслан Белый и Ирина Приходько рассуждают о разнице жизни в разных странах. Лёгкое шоу и минусах и плюсах в бытовой жизни.  Руслан Белый: https://www.ingram.com/ruslan_belyy_  Ирина Приходько: https://www.ingram.com/irinozavr  на платформе concertplace.tv можно посмотреть концерты Руслана Белого и Иры Приходько  #standup #стендап #Белый #РусланБелый #Приходько',
#  'Ну что, вот и подходит к концу этот год. Год взлетов и падений. Год радости и улыбок 🫀  Если честно, то для меня он был безумно продуктивным, чему я очень рада! Путешествия за границу, проекты, телевидение, мероприятия, новые знакомства и конечно же вы! Да, что я рассказываю? Вы сами все видели каждый день!  Мне кажется , что за этот год я прожила все пять!  Сложно? Да! Интересно? Безумно! Именно приятная усталость несет настоящую ценность в эту жизнь!  Творите и верьте в себя! Верьте! Без веры - никуда!   А я продолжаю дальше идти к своей цели! Кстати, вкину вам одну новость… В следующем году мы встретимся лично! Лично на моих концертах! Обняла 🫂  Подписывайся на @kesler_ksu  #рекомендации',
#  'Всем кулюм булюм🌸  https://vk.com/video-211232966_456240094',
#  'Братва начался стрим в тиктоке  https://vt.tiktok.com/ZSNnyopkS/ Всех жду 🥰',
#  'Неудачные дубли хотите?🤣  Да! Такое редкое бывает, но всё же бывает, ловите маленький тизер блуперсов и неудачных дублей!🤣  А полную версию можно посмотреть в нашем Закрытом чате - https://boosty.to/lazarevanton/about ☄️  😃Уписяетесь со смеху😃',
#  'Братва, стрим сегодня в 19:00 по МСК, в ТикТоке ❤️',
#  'Насладитесь изысканным вкусом MacCoffee Cappuccino di Torino https://ozon.ru/t/arRKzPM  Это Старый выпуск «Можно ваш телефончик» который еще не был представлен в  YouTube. Был в ВК но там его почти ни кто не посмотрел. Такой бриллиант нам жалко терять и мы выкладываем его сейчас, чтобы поднять вам настроение перед Новым годом. Благодаря рекламе вы можете смотреть его бесплатно, поэтому наслаждайтесь всем что увидите внутри. Приятного просмотра.   Больше меня тут:  ТГ:  https://t.me/sobolevtelergam Паблик ВКОНТАКЕТ: https://vk.com/public161938332  По вопросам рекламы на моем канале: commercial@sobolev-tut.ru По вопросам организации концертов: Нина 8-911-973-02-46  Смотри еще ⬇️⬇️⬇️ :  ♥️ Сольный концерт 2020 на ТНТ : "Семья - Боль". Концерт можно посмотреть на платформе PREMIER.  ♥️ Сольный концерт 2020: "В поисках моей аудитории" https://www.youtube.com/watch?v=t2uVHwGphR4  ♥️ Сольный концерт 2018: "StandUp не на ТНТ" https://www.youtube.com/watch?v=0Yq9dCNpX1U  ♥️ Концерт 2017  "Ходит по сцене и орет":  https://www.youtube.com/watch?v=GH6wq7jexCk   #StandUp #Соболев #Стендап #Камеди #Comedy #Комик #Блог #Смешно #sobolev #Прожарка #Соболь #Стэндап',
#  'А ещё посмотрите наш новогодний FONBET-огонёк  Собрали почти всех амбассадоров, поиграли, выбрали проекты, которые Fonteam в 2024 году будет реализовывать  Смотреть тут https://www.youtube.com/watch?v=WTNvSFrfM6Q',
#  'Всё, в этом году шутки кончились. А песни в музыкальном фильме VK под шубой 2 – нет! Поэтому завтра 29 декабря  в 20:24 встречаемся с вами в VK Видео и настраиваемся на новогоднюю волну вместе!  Реклама. ООО «В Контакте». ИНН 7842349892. erid 2Vtzqw8Lceg.',
#  'НОВЫЙ ВЫПУСК Мурашкина подкаст   https://youtu.be/tGWWwFVrAJA',
#  'Мой Youtube канал 👉  https://youtube.com/@VladislavCherevatyi?si=v4qSb_PDeZGNztUJ  Прикреплённые ссылки: 🔗 https://youtube.com/@VladislavCherevatyi?si=v4qSb_PDeZGNztUJ',
#  'Итак, друзья. Премьера года намечена на субботу. 30 декабря  @artemmaltsev004 @AMRomanov',
#  'ЭТО ВИДЕО ТРОНЕТ ВАС ДО СЛЕЗ!🥲❤️  https://youtu.be/7_55jC4fGI0',
#  'Chappellepozvonit https://t.me/Chappellepozvonit/863    Пока я смеюсь над шутками, которые вы прислали мне в бот, вы посмейтесь над отборными приколами от Насти Веневитиной из нового выпуска «10 смешных вещей из интернета». Это формат, в котором люди, которые смешат меня, рассказывают о том, что смешит их.  П Настя Веневитина: 10 смешных вещей из интернета 1 Когда все начинают делиться своими угарэсами, я всегда вспоминаю про это видео. Меня в нем веселит то, что столько нелепых событий происходят в один момент. А еще подпись. Пса ограбили. \xa02 Фильм «Братья из Гримсби». Очень много сортирного юмора, яиц, спермы и т.д. Но гэгом с вентиляторами в конце он заслужил свое место в рейтинге! \xa03 Меня веселит вообще весь контент с животными. Я даже, если честно, подписана на аккаунт пуделя Груши и на кота Степана. Звучит тупо, но я не знаю, как с них можно не умиляться.\xa0… 🔗 https://telegra.ph/Nastya-Venevitina-10-smeshnyh-veshchej-iz-interneta-12-26',
#  'https://vk.com/wall-27477591_65212  П Иван Абрамов 🎙Сольный концерт Ивана Абрамова о самых важных «девочках».  📍Санкт-Петербург 2023. Эксклюзивно в VK Видео👇 🔗 https://vk.com/wall-27477591_65212',
#  'После этого видоса любой научится делать снежинки❄️   https://rutube.ru/video/d82a874985f0b50dd6ecb89031788722/  П БИТВА СНЕЖИНОК, КАК СДЕЛАТЬ САМУЮ НОВОГОДНЮЮ СНЕЖИНКУ Оцениваем у кого лучше снежинка Битва на скорость, на похожесть и на ажурность 🔗 https://rutube.ru/video/d82a874985f0b50dd6ecb89031788722/',
#  'НИ К ЧЕМУ НЕ СТРЕМИСЬ И ВСЁ УСТРЕМИТСЯ К ТЕБЕ эфир от 21.12.23  Поддержать Епифанцева финансово а так же посмотреть запись в хорошем качестве можно на бусти: https://boosty.to/epifania/  ℹ️ Размер прикреплённого видео-файла превышает 150 Мб',
#  'А вот и Серхио Рамос запел! 🙈 Сине-бело-голубое небо…  Испанец записал трек и даже выпустил клип с группой Los Yakis.  🕺🏻С учетом того, что Рамос родом с юга из Севильи, дебют получился ярко стилизованным в стиле любимого Серхио фламенко 💃🏻  https://youtu.be/-TZgVqJlahI?si=qM4WCiKOsqVaGjVj  @akulininmatch  П LOS YAKIS, SERGIO RAMOS – NO ME CONTRADIGAS (Videoclip Oficial)  @sergioramos LOS YAKIS, SERGIO RAMOS – NO ME CONTRADIGAS (Videoclip Oficial)      LOS YAKIS se unen a @sergioramos  para regalarnos en estas navidades un tema que alegrará esta temporada festiva. "NO ME CONTRADIGAS".  Ya disponible en todas las plataformas musicales.  💫FELICES FIESTAS💫  Sigue a Los Yakis y a Sergio Ramos en todas sus cuentas:   🔥LOS YAKIS: ingram: https://www.ingram.com/losyakisoficial/ TikTok: https://www.tiktok.com/@losyakisoficial YouTube https://www.youtube.com/@LosYakisOficial: Facebook: https://www.facebook.com/profile.php?id=100057914388013    🔥SERGIO RAMOS:   ingram:  https://www.ingram.com/sergioramos/  TikTok: https://www.tiktok.com/@sergioramos   YouTube: https://www.youtube.com/channel/UC_ixBF2BWlWc9Bxo7fReiSA Facebook: https://www.facebook.com/SergioRamosOficial   Director Video: Benny Terán      ℗ OCKAM RECORDS SL   #felicesfiestas   #flamenco  #salsa 🔗 https://youtu.be/-TZgVqJlahI?si=qM4WCiKOsqVaGjVj',
#  'Новые приключенцы уже в сети!   Окунуться в мир странствий с нами можно ➡️ тут',
#  'Опубликован комментарий к записи: https://vk.com/wall1950148_6025  https://vk.com/video-220728319_456239150',
#  'Подписывайтесь на мой телеграм канал.  Теперь там будет интересно!  Ну что, вчера закончился один из лучших сезонов шоу «Звезды в Африке»  И теперь я могу делиться с вами эксклюзивными кадрами с бэкстейджа.  https://t.me/galustyanmichael/397  Прикреплённые ссылки: 🔗 https://t.me/galustyanmichael/397',
#  'Киношники! Сегодня стрим в 18:00 в ТикТоке 😎  Всех очень жду, хочу  рассказать свои впечатления от просмотра нового фильма)',
#  'Как вы, мои хорошие? Все в такой же новогодней суматохе? Всю неделю, а то и несколько сплю по 3-4 часа🙈  И я даже подумала, что сейчас бы не помешал тур куда-нибудь далеко 😍 чтобы выспаться хотя бы в дороге! 😅 Может Владивосток? Отличный вариант, тем более, что Москва и Владивосток стали одновременно победителями в голосовании на молодежную столицу России 2024! 🔝  И это значит, что весь следующий год будет ярким сразу между двумя такими красивыми городами и свяжет всю нашу большую страну. Очень неожиданно и интересно как это пройдёт. Я люблю Владивосток 🌊 но, конечно, всегда выберу Москву, тут я живу, тут я счастлива 🥰  А какой город бы выбрали вы?',
#  '25 юбилейный выпуск шоу «Кстати» уже на VK ! Ну и песенка новая «Хоккей» группы @obezyanavteploivode  тоже там ! Ну и тут теперь тоже )',
#  'ХОККЕЙ Группа "Купание обезьяны в тёплой воде" 🙉']

# %% [markdown]
# ## <CENTER> **`2.` Очистка данных**
#
# На данном этапе проведём следующую предобработку:
#
# * Приведём данные к нижнему регистру;
#
# * Удалим пунктуацию, эмодзи и специальные символы;
#
# * Удалим лишние пробелы;
#
# * Удалим дубликаты.

# %% [markdown]
# #### $2.1$
#
# Создадим функцию для предобработки:

# %%
# Функция для очистки текста
def clean_text(text):
    
    """
    Очищает текст, приводя его к нижнему регистру и удаляя пунктуацию.

    Args:
        text (str): Входной текст для очистки.

    Returns:
        str: Очищенный текст в нижнем регистре, без пунктуации и лишних пробелов.
    """
    
    # Приводим к нижнему регистру
    text = text.lower()
    
    # Удаляем пунктуацию, эмодзи и специальные символы (оставляем буквы, цифры, пробелы)
    text = re.sub(r'[^\w\s]', '', text)
    
    # Удаляем лишние пробелы
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %% [markdown]
# Применяем полученную функцию к данным:

# %%
# Очищаем документы
cleaned_documents = [clean_text(doc) for doc in documents]



# Выводим результат
print('Результат после очистки данных:')
print('-' * 35)
print()

display(cleaned_documents)
# Out:
# Результат после очистки данных:
# -----------------------------------
# ['твой лучший секс спрятан здесь делюсь каналом дипломированного сексолога крис взломала код классного секса мастерски раскрепощает знает миллион горячих техник и лучшие девайсы для взрослых самые полезные посты здесь отрезвляющий пост я все сама прокачай наездницу ролевая игра vip кинотеатр техника оральных ласк как занимается сeксом неудобная женщина кстати крис провела трехдневный безоплатный онлайн интенсивот бревна до богини совместно с врачом и владельцем сексшопа скорее смотри записи пока не удалила httpstmesekretskris1048 здесь жарче чем в аду',
#  'кнопка starthttpstmemajorstartstartapp1972869792',
#  'а продолжение где правильно в моем сообществе в вк ссылка в шапке профиля',
#  'тем временем моя авторская телега уверенно в тройке сильнейших компания мощная ухххх',
#  'у меня есть двоюродная сестра у нее есть сын антон мой двоюродный племянник получается он снимает свой подкаст конечно я пришла его поддержать получилось честное и откровенное интервью смотрите httpsyoutubeaifyxpjaa1qsimh4_bwskrakkcmv',
#  'тем временем моя авторская телега уверенно в тройке сильнейших компания мощная ухххх',
#  'мои ученики ко мне возвращаются мои волшебные вы не представляете насколько круто и приятно когда мои ученики с других курсов и потоков вновь возвращаются ко мне на обучение и тем более под мое наставничество главное преимущество виптарифа это мое чуткое руководство я вам подскажу направлю и помогу хотите начать путь в мир эзотерики и мантики с опытным наставником тогда жду вас на собеседовании переходите по ссылке и записывайтесь httpswame79043358533',
#  'на ютюб канале olympics эти дни и сейчас идут прямые трансляции соревнований проверяла без vpn видимо там и церемонию открытия покажут вот ссылка нужно выбрать вкладку трансляции httpsyoutubecomolympicssidx1tervagjgayeto п olympics welcome to the olympics youtube channel where the games never end from the best musical moments at the olympic games in our music monday series to weekly compilation videos with highlights from the olympics on fridays plus exclusive documentaries about the stories behind the glory this is where you can find everything about the biggest sporting event in the world httpsyoutubecomolympicssidx1tervagjgayeto',
#  'смотреть httpsyoutubeepu_3sy7os п раздевалка 12 сергей орлов и александр пташенчук баскетбол или бацкетбол вам сюда httpsmediumsportru как правильно произносить название нашей любимой игры баскетбол или бацкетбол у сереги орлова есть своя версия смотри выпуск раздевалки и узнаешь как верный ответ дада саша пташенчук тоже был в шоке наш тг httpstmemediumbasket хочешь смотреть больше баскетбольных видео инсайды бэкстейджы и не вошедшее будет на канале medium basket shorts подписывайся mediumbasketshorts httpsyoutubeepu_3sy7os',
#  'сегодня день рождения матвея кисляка и этот выпуск молодого подкаста мы готовили как подарок юному армейцу ровно год назад он дебютировал за цска и забил первый гол а теперь он свободно рассуждает о жизни о гвардиоле и кройфе и точно знает что хотел бы стать тренером а ведь ему только что исполнилось 19 лет клик чтобы получить удовольствие от взрослого разговора с юношей абсолютное открытие httpsyoutubev4ywwqjkgm8sibp4zt4z4zj2m7y3l п кисляк матч против матеуса игры в бразилии и мечта стать тренером молодой подкаст 2 матвей кисляк рассказал эду и нагучеву про свою футбольную карьеру второй выпуск молодого подкаста с восходящей звездой цска детство в старом осколе и соседство с емельяненко матч против легенд футбола перед стартом чм2018 посещение футбольного места силы в бразилии телега нагучева httpstmeoffearth телега эда httpstmeededik ютубканал эда httpswwwyoutubecomedams19 следите за юфл и мфл в наших соцсетях и на сайте сайт httpsyflrussiaru юфл в вк а также обзоры интервью и записи игр тут httpsvkcomyflrussia мфл в вк а также обзоры интервью и записи игр тут httpsvkcommflrussia telegram юфл httpstmeyflrussia telegram мфл httpstmemflrussia дзен httpsdzenruyfl httpsyoutubev4ywwqjkgm8sibp4zt4z4zj2m7y3l',
#  'какая карта укажет на масика распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base прикреплённые ссылки httpalexeygrishincomlenorman_base',
#  'какая карта укажет на масика распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base',
#  'сегодня 2607 премьера в 1800 мск долгожданный выпуск с id1868874евгений егоров httpsyoutubea4hbdcgpjzisikruzkulyq2gp_8fp',
#  'отзыв от юлианны распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base деятельность компании meta запрещена на территории российской федерации и признана экстремистской прикреплённые ссылки httpalexeygrishincomlenorman_base',
#  'таропрогноз на 26 июля тройка жезлов совет тройка жезлов карта роста стабильности и успеха чего бы не касался вопрос личных отношений карьеры духовного роста эта карта советует продолжать двигаться вперед выходить за пределы нынешних границ по этой карте идут вдохновение и реализация идей они обретают форму и получают направление она обещает благополучный исход дела деньги стабильное положение и дальнейшее процветание успешное решение вопросов прекрасные возможности для дальнейшего улучшения ситуации финансовые успехи благодаря разумному поведению тройка жезлов означает коммерческий успех и вообще показывает человека занимающего прочное положение и имеющего надежный тыл любовь тройка жезлов та карта которая традиционно считается залогом счастья она говорит что печали и неприятности останутся позади раскрываются все возможности для построения благополучной жизни а в отношениях все будет хорошо весеннее настроение и сексуальная гармония распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base',
#  'отзыв от юлианны распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base деятельность компании meta запрещена на территории российской федерации и признана экстремистской',
#  'roast battle на ютубе httpsyoutubelgzll8loi8csim5k3uhoyu2paia2j',
#  'всегда приветствую появление новых динамовских каналовстраницконтента сегодня рекомендация подписаться на динамовского болельщика из эстонии несмотря на все логистические сложности выбирающегося на игры динамо неординарный подход к оценке выступления футболистов на примере игры с факелом прошу httpsdzenruazp98slpeixpgbmxj п динамо москва факел подробный обзор статья автора futbolofyl в дзене динамомосква факел 31 яркое начало анализируем игру каждого игрока динамо решения тренерского штаба работу судей и комментаторов httpsdzenruazp98slpeixpgbmxj',
#  'spartakoz httpstmespartakoz9847 давно хотел сделать видеопроект о спартаке и вот с моими партнерами из winline получилось вашему вниманию спартак шоу в первом выпуске вместе с сабиной ромбиновной актериной и свиным рылом обсудили поражение от оренбурга но еще дали пару инсайдов по трансферам спартака объяснили поведение соболева и почему зенит не хочет его брать прямо сейчас поговорили о станковиче почему у него может получиться в спартаке разобрали межсезонье барко и виллиана жозе поболтали о том что ждет спартак очень скоро объявили розыгрыш футболки и маски свиного рыла которую он впервые снял публично ну и постарались разогнать печаль после кошмарного старта срочно врубайте подписывайтесь а еще на телеграмканал спартак шоу чтобы ничего не пропустить и пишите комменты httpsyoutube_xl0drioio0 п старт рпл станкович соболев и где барко спартак шоу 1 друзья мы запускаем спартак шоу в первом выпуске обсуждаем поражение спартака от оренбурга в первом туре рпл станковича соболева трансферы и инсайды наши ведущие макс никитин httpstmespartakoz сабина актерина httpstmeakterinatv антон милёшин httpstmepigesface 0000 первый выпуск спартак шоу 0048 деанон свиного рыла 0142 идеи станковича не сработали что дальше 0500 обсуждаем стартовый состав и соболева 0939 почему спартак не подготовился к забросам оренбурга 1330 подходит ли состав под станковича 1630 яркие цитаты межсезонья 2451 как спартак нашёл станковича почему не слишкович 3255 какие плюсы у нового тренера спартака 3553 позитивный момент в поражении от оренбурга 3740 как тренирует станкович 4055 прогноз от суперкомпьютера 4510 молодые футболисты в спартаке 4735 трансферы где барко 5129 виллиан жозе и лишний вес нужна помощь артема реброва 5915 какие позиции рассматривает спартак на усиление 010030 инсайды 010400 покинет ли соболев спартак 010747 вернется ли промес в спартак 011111 прогнозы на август 011345 могли прийти но не пришли httpsyoutube_xl0drioio0',
#  'я вроде не садист но мне так понравилось издеваться над людьми что я точно буду это дело продолжать ребят а гляньте пожалуйста моё новое шоу оставьте отзыв и предложите нововведения очень нужна обратная связь шоу олег олег шоу олег олег шоу олег олег',
#  'через 10 дней лечу в париж на олимпийские игры почти все буду постить в телеге подписывайтесь httpstmeemma_figuristo4ka надеюсь у меня все получится ps и кто бы что не говорил а все равно по сей день каждая федерация и организаторы мероприятий прописывая регалии того или иного спортсмена всегда начинают с олимпийских достижений и даже если спортсмен ничего не завоевал гордо пишут участник олимпийских игр поэтому и мы будем гордиться каждым спортсменом кто доедет выступит в париже вот я на олимпийских играх не выступала и очень об этом сожалею восполняю тем что на них работаю но это другое дмитрий челяпин поймал на футболе прикреплённые ссылки httpstmeemma_figuristo4ka',
#  'у моей подруги и коллеги которой я уступила место уже в нескольких фильмах но все также любимой и вдохновляющей вышел трек не слушаете если плохое настроение httpsmusicyandexrualbum32209395track128400484utm_mediumcopy_link п юху anna glaube слушать онлайн на яндекс музыке anna glaube трек 2024 httpsmusicyandexrualbum32209395track128400484utm_mediumcopy_link',
#  'httpsvkcomwall225813819_84 срочно нужен кофе',
#  'как найти смысл жизни в момент когда кажется что совсем его нет как найти в себе силы двигаться дальше и понять самое ценное что есть у тебя это ты сам ищите ответы в новом выпуске шоу открытый прием httpsyoutubeqvh4twy9kww',
#  'ходили пьяные на мероприятия artemvinokur подкаст гадзилы с женей сидоровым на ютуб канале',
#  'таропрогноз на 23 июля туз мечей совет меч это достаточное количество сил для энергичных начинаний огромная решимость действовать начало успешной борьбы готовность к росту отрыву от изначального существования это ситуация когда сам человек для себя многое прояснил и знает теперь что хочет делать дальше это показатель силы физической силы силы воли силы приобретенной положением и умом или в силу обстоятельств триумф личной силы власти над обстоятельствами триумф может относиться к любой стороне жизни к работе любви денежным делам духу любым увлекающим занятиям этот туз не столько начало но и показатель завоеванного торжества провозглашенных взглядов и принятых решений деньги процветание принятие однозначных и окончательных решений в этих вопросах возможность улучшить качество жизни приняв вызов любовь в области отношений туз мечей символизирует импульсивную первобытную силу интенсивные завоевательные эмоции крайние чувства связанные с ситуацией или человеком эмоции которым покровительствует туз мечей способны воспламенить таким огнем который сожжет все препятствия на пути к цели попутно причинив немало вреда мечи вообще масть холодная и когда на горизонте в които веки появляется единственная эмоция то она заполоняет собой всё со свойственной этой масти тотальностью распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base',
#  'можно ли прощать побои супругу ответы ищите в новом выпуске шоу открытый прием httpsyoutubeqvh4twy9kww',
#  'comment_show httpstmecomment_show8012 вот он первый лайв нового сезона чемпионат россии вернулся ждали очень сильно прямо очень без раскачки врываемся в старый местами добрый диалог о первом туре банда такая шнякин генич казанский арустямян стол тоже будет понедельник не забудь велком youtubeg0kbx006q18',
#  'сумасшедшая семейка или один новый формат добро пожаловать за кулисы теперь эксклюзивно на rutube будут выходить влоги про мою жизнь там я расскажу о том что не попало в фокус сми и социальных сетей покажу себя в естественной среде обитания и буквальном смысле с двумя детьми на шее в первом выпуске вы увидите как прошла наша гендерпати кого мы с артуром ждали мальчика или девочку а также как на самом деле дочки отреагировали на новость о беременности переходите скорее на рутьюб и пишите в комментариях как вам наше безудержно энергичное семейство поддержите артура за участие в этом мероприятии ссылка в шапке профиля',
#  'httpstmestimzhur4320 недавно в лондоне пару свободных часов я потратил не на паб или шоппинг а на стадионный тур и ни в коем случае не жалею потому что это был колоритнейший крейвен коттедж вы тоже думаю не пожалеете если составите мне компанию тем более там разыгрывается футболка ссылка сообщение закреплено',
#  'сходил в гости к пацанам поговорили за деньги и не только httpsyoutubefc0i_aoamns п миллион от первого канала деньги от спонсора зарплата на нтвплюс лудомания мудрая жена foodband доставит пиццу роллы лапшу курочку лимонад круглосуточно скидка до 25 на все заказы по промокоду деньги в приложении foodband httpsbitly35qaaas или на сайте httpsclckru3bw2gv константин генич новый гость подкаста за деньги как завершить футбольную карьеру и найти себя в другом как первый канал предлагал около миллиона рублей в месяц а константин отказал как справиться с лудоманией и держать себя в руках как буки переманивают амбассадоров как встретить ту которая будет поддерживать тебя во всем вы его слушали во время финала евро2024 а вот вам еще 100 минут 0000 начинаем 0010 почему генич лучший 0429 про детство константина 0729 можно и поесть 1009 продолжаем про детство и молодость 1827 образование футболистов как генич расширял свой кругозор 2045 первые деньги 2512 начало футбольной карьеры и увеличение заработков 2720 траты на старте карьеры 3039 длительные загулы 3405 константин генич геройлюбовник 3604 дает ли константин в долг 3903 глупые вложения денег 4542 первые шаги после завершения футбольной карьеры выход из зоны комфорта 5254 мне повезло что в какойто момент я оказался рядом с васей 5840 футбольный клуб 10242 всплеск карьеры константина 2018 год и что предшествовало ему 10705 тот самый репортаж под градусом из бразилии вместе с черданцевым 10948 вернемся в 2018 как его провел генич увеличение заработка предложение от первого канала и обещания которым не суждено было сбыться 11740 ставки и лудомания 12701 как константин относится к рекламе букмекеров будучи амбассадором одного из них 12938 про доходы гонорары спонсоров и переманивания в сфере букмекеров 13415 история знакомства с женой и отношения спустя 15 лет успешного брака 13940 завершение httpsyoutubefc0i_aoamns',
#  'утро не могло стать горячее но именно сегодня вышла дерзкая готовка с оксаной самойловой как никогда вовремя в начале выпуска специально для моего youtubeканала оксана дала эксклюзивный комментарий в котором в деталях и со спойлерами рассказала о своих эмоциях после участия в своем первом реалити выжить в дубае возвращение коснулись темы отношений с викторией боней после съемок рейтингов азарта а ещё оксана объяснила почему зрителям не получится понять юмор звездной команды всё с пылу с жару одно из самых насыщенных интервью скорее переходите по ссылке чтобы посмотреть новый выпуск шоу ляйсан утяшева',
#  'послание от вселенной на новую неделю чтобы принять это послание и воплотить его в жизнь напишите в комментариях принимаю распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base',
#  'сегодня исполнилось 87 лет со дня рождения эдуарда стрельцова возможно самого талантливого футболиста который рождался в нашей стране 4 года назад мы делали о стрельцове небольшое кино там очень мало про историю на даче которая обернулась для стрельцова тюрьмой гораздо больше про масштаб таланта и личности эдуарда и еще про фильм стрельцов который тогда только вышел на экраны и мгновенно подвергся пламенной критике в этом фильме снялся мой товарищ денис казанский мы поговорили и с ним и с режиссером картины ильей учителем а еще с юрием семиным который играл против стрельцова с другом стрельцова михаилом гершковичем со станиславом гридасовым подробно изучавшим материалы дела и с александром шмурновым яростно раскритиковавшим фильм httpsyoutubehrmxqdd7taasiezuuvzsbrzyz2vro п что мы знаем о стрельцове кем он был для мирового футбола каким он показан в фильме стрельцов эдуард стрельцов возможно главный талант русского футбола уже в 17 он дебютировал за сборную ссср оформив хеттрик в игре против швеции в 18 стал лучшим бомбардиром чемпионата советского союза а еще спустя год олимпийским чемпионом спустя 2 года он должен был ехать на чемпионат мира в качестве главной звезды советской сборной но за день до отъезда на турнир был арестован по обвинению в изнасиловании какой могла получиться карьера стрельцова если бы не 5 лет в тюрьме и 2 года отлучения от футбола какие качества позволили стрельцову спустя 7 лет вернуться в футбольный топ и дважды стать лучшим игроком ссср в чем был феномен популярности стрельцова что такое стрельцовская пятка и реально ли представить стрельцова в современном футболе мы поговорили с людьми которые знали стрельцова играли против него или следили за его карьерой мы встретились с режиссером фильма стрельцов ильей учителем и поговорили с ним о критике сценарных нестыковок и исторических неточностей каким был показан в фильме стрельцов и похоже ли это на правду смог ли александр петров передать образ легендарного игрока каким увидели фильм те кто знал стрельцова и те кто следил за его карьерой этот фильм дань памяти легенде советского футбола и его игре о стрельцове говорили юрий семин играл против стрельцова михаил гершкович играл и дружил со стрельцовым геннадий орлов видел игру стрельцова александр шмурнов рос на рассказах о стрельцове илья учитель снял фильм о стрельцове денис казанский сыграл в фильме о стрельцове станислав гридасов изучал историю стрельцова пс большой подкаст станислава гридасова посвященный эдуарду стрельцову можно послушать по ссылке httpswwwyoutubecomwatchvd3ho0b0prngt1810s мой ingram httpswwwingramcommossakovskiy мой twitter httpstwittercommossakovskiy мой telegram канал httpstdorumossakovskiy что мы знаем о стрельцове кем он был для мирового футбола каким он показан в фильме стрельцов httpsyoutubehrmxqdd7taa httpsyoutubehrmxqdd7taasiezuuvzsbrzyz2vro',
#  'мы уже в эфире скорее переходите по ссылочке httpsstartbizon365ruroom163462lenorman1 не опаздываем',
#  'увидимся через час встречаемся в 1200 по мск по ссылке httpsstartbizon365ruroom163462lenorman1 все готовы пишите ваши ожидания от урока и курса в целом',
#  'влог с юга httpsyoutubeivobhyjl3re п влог с юга вашурина никитушка и катеринка сняли свое недельное путешествие на камеру и вот что из этого вышло приятного просмотра точки отдыха отель radisson blu rostovondon гростовнадону для подписчиков моего канала у нас есть промокод trip который дает скидку 10 на проживание в отеле radisson blu rostovondon глемпинг villey uley гсочи для подписчиков моего канала у нас есть промокод vashourina который дает скидку 10 на проживание до 291224 кемпинг 9 километр гджубга для подписчиков моего канала у нас есть скидка 10 на проживание в сафаритенте соцсети ведущих ingramcomvashourina ingramcomes_zaytseva ingramcomkulakov_ns монтажёра превью мейкера ingramcomfrogsoill httpsyoutubeivobhyjl3re',
#  '1 вводный урок в чём отличие ленорман от других мантических предсказательных систем и от таро рад презентовать вам моё первое видео вышедшее в рамках знакомства с таким потрясающим мантическим инструментом как оракул ленорман ссылка на 1 видеоурок марафона httpsyoutubenlepfgvgbvk для всех тех кто жаден до новых знаний кто всегда стремится узнать чуть больше остальных кто хочет разобраться с предметом кому недостаточно шапочного знакомства стартовал наш марафон итак в чём же принципиальное отличие ленорман от таро и почему я рекомендую начать своё знакомство с миром мантических инструментов с оракула ленорман 1 ленорман гораздо проще и быстрее усваивается но это не значит что оракул чемто хуже таро просто это совершенно разные системы с разным подходом и полем применения ленорман это универсальная колода которая отлично подойдёт для ответа на какието бытовые вопросы ответы формата данет диагностику здесь и сейчас прогнозирование событий в отличие от карт таро оракул ленорман не подойдёт для ответов на вопросы о смысле жизни и о реинкарнационных смыслах то есть карты таро близки к психологотерапевтическим методам а ленорман удобнее в социальных и бытовых вопросах 2 следующее существенное отличие двух инструментов работая с оракулом ленорман крайне важно отслеживать то как именно и в каком порядке расположены карты в раскладе как взаимодействуют друг с другом рисунки на них вплоть до того как и куда смотрят лица персонажей а ещё в ленорман мы не трактуем перевёрнутые карты как это делается в таро 3 во многих колодах ленорман мы можем на поле карты увидеть её игральное значение оно никогда не трактуется потому что появилось лишь в процессе исторического синтеза кстати а вы в курсе что сама ленорман никогда не видела оракула ленорман а использовала в своих предсказаниях обычную игральную колоду на базовом курсе оракул ленорман базовый курс следующая ступень после марафона на первом уроке я рассказываю как так вышло и почему мы пользуемся другой колодой и даю ещё много знаний делюсь секретными фишками и своими собственными ноухау ссылка на 1 видеоурок марафона httpsyoutubenlepfgvgbvk распродажа курса оракул ленорман базовый курс в рассрочку httpalexeygrishincomlenorman_base служба поддержки по всем вопросам а также по вопросам записи на бесплатное собеседование на vipтариф курса оракул ленорман базовый курси оплаты 79043358533 telegram whatsapp прямая ссылка на waдиалог со службой поддержки httpswame79043358533 п бесплатный курс ленорман с нуля урок 1 в чем отличие ленорман от таро базовый курс оракул ленорман с 50 скидкой httpsalexeygrishincomlenorman_base все скидки и акции httpstaplinkccgrishin1309 секретный клуб grishin club httpalexeygrishintildawsvip_tg официальный сайт httpsalexeygrishincom telegram httpstmealexeygrishin youtube httpswwwyoutubecomcalexeygrishintarot vk httpsvkcomalexgrishin группа vk httpsvkcomtarotlenorman ozon httpsozonrutjzxa8e2 служба поддержки по всем информационным и техническим вопросам а также по всем вопросам сотрудничества и оплаты 79043358533 telegram whatsapp прямая ссылка на waдиалог со службой поддержки httpswame79043358533 httpsyoutubenlepfgvgbvk',
#  '4 серия уже на канале срочно нужно ваше мнение о путешествии смотреть',
#  'дорогие друзья по вашим многочисленным просьбам мы продолжаем исторические кулинарные лекции с id51547887татьяна цветкова и сегодня тема петербургская кухня это уникальный гастрономический феномен возникший в результате слияния двух культур традиционной русской кухни и изящной французской с некоторыми добавлениями других национальных кулинарных рецептур не пропустите и самого приятного вам просмотра httpsyoutubebyxu0bfujgsiwjphm7u496jkh8wh прикреплённые ссылки httpsyoutubebyxu0bfujgsiwjphm7u496jkh8wh',
#  'почему люди познают любовь через боль ответы ищите в новом выпуске шоу открытый прием httpsyoutubeqvh4twy9kww',
#  'существует миф о том что уколы красоты вызывают привыкание со стороны кожи на этот счет было проведено множество исследований которые доказали что препараты лишь выполняют свою функцию а привыкание возникает лишь на психическом уровне тут срабатывает психосоматика пациент начинает внушать себе что красоту можно спасти только с помощью постоянных инъекций это называется дисморфофобией расстройством личности при котором человек чрезмерно обеспокоен и занят незначительным дефектом или особенностью своего тела согласно статистическим данным от 15 до 29 людей страдают этим расстройством что заставляет миллионы женщин ложиться под нож и какие триггеры тут срабатывают смотрите в новом выпуске шоу открытый прием переходите по ссылке для просмотра httpsyoutubeqvh4twy9kww',
#  'страх перед свекровью не норма учимся понимать мать мужа премьера новой 3 серии подкаста лунные сутки с алексеем гришиным в качестве ведущего лунные сутки это уникальный подкаст в котором можно и поржать и нырнуть на глубину на самой настоящей таросессии 3 серия подкаста лунные сутки с алексеем гришиным httpsyoutube0vfewbogpc8',
#  'skz продлили контракт а я ролик выложилпосмотри пошли пожалуйста httpsyoutubekzqgx66p6tosifauzkxfjqi21gri п booklog топ 3 книги этой недели вы просили очень давно показать вам топ моих книгрубрика booklog созданна специально для тогочтобы поделится с вами моими любимыми книгами httpsyoutubekzqgx66p6tosifauzkxfjqi21gri',
#  'мужчина по судьбе и по звезде полная версия уже на моем youtubeканале по ссылке httpsyoutubeo6tovkagsg скидка на розовый кварц httpsozonrut9agdg77',
#  'опубликован комментарий к записи httpsvkcomwall161938332_7842 ссылочка httpsyoutubera1whrmyp3usiwhu3thqbipinvs8',
#  'премьера 22 серия 2 сезона токшоу кадони шоу под названием ставки сделаны на тв3 с участием алексея гришина httpsrutuberuvideo9e77f7f17432d03550091c0b9b6660fe',
#  'премьера 22 серия 2 сезона токшоу кадони шоу под названием ставки сделаны на тв3 с участием алексея гришина httpsrutuberuvideo9e77f7f17432d03550091c0b9b6660fe',
#  'премьера 22 серия 2 сезона токшоу кадони шоу под названием ставки сделаны на тв3 с участием алексея гришина httpsrutuberuvideo9e77f7f17432d03550091c0b9b6660fe прикреплённые ссылки httpsrutuberuvideo9e77f7f17432d03550091c0b9b6660fe',
#  'лев толстой говорил не красота вызывает любовь а любовь заставляет нас видеть красоту и знаете не каждый это понимает миллионы женщин которые не принимают себя и свою естественную притягательность ктото боится старости комуто просто не нравится в себе чтото а другие же думая что изменив внешность до неузнаваемости смогут поменяться изнутри а может и поменять свою жизнь но все это иллюзия потому что от себя не убежишь какой бы формы не был у тебя нос какую цифру показывает паспорт вся эта смена внешности чаще всего не всегда приводит к обрывает естественную красоту стирает обаяние делая всех одинаковыми бездушными и безликими скажите есть ли то что вы бы хотели в себе изменить поделитесь какой от этого ждете выхлоп я очень надеюсь что новый выпуск шоу открытый прием даст ответ на этот вопрос httpsyoutubeqvh4twy9kww',
#  'elenalande_chef httpstmeelenalande_chef1151 друзья если вдруг вы пропустили наш с андреем атласом шортс о том как вкусно приготовить рыбу httpsyoutubecomshortscgvikro9e6csinmerag_sytpqbb п домашний рестик снова экономим и отбираем чьюто прибыль атлас рыб красных shorts домашний рестик снова экономим и отбираем чьюто прибыльатлас рыб красныхгравлаксвариант 11свекла уже кемто отваренная и даже почищенная 2шт2рыба кра httpsyoutubecomshortscgvikro9e6csinmerag_sytpqbb',
#  'скоро на моем ютубчикевыйдет рубрика booklog вы просили рассказать вам о книгах которые я читаюа я решил посвятить этому целую рубрику httpsyoutubecomkagramanasifddmgv5eq_gbrcii',
#  'ритуал со свиданиями на новые отношения полная версия уже на моем youtubeканале по ссылке httpsyoutubeo6tovkagsg скидка на розовый кварц httpsozonrut9agdg77',
#  'такой бодрой раздачей я начинал свой стрим на nl5000 в рамках челленджа амбассадоры vs хайроллеры в день старта а сегодня с 1800 сражаются дима шахов и дамир жугралин эти лютые супердорогие для нас кэшсхватки можно смотреть в прямом эфире по ссылкам httpsyoutubecomlivevhggtwt1nrqfeatureshare httpstwitchtvpokerok_officialhome httpskickcompokerokstreams напомню что каждый из нас пытается преумножить призовой фонд турнира кубок котэ который состоится 6го июля половина стека после 3х часов на nl5k пойдет в награду за выбивание амбассадора на кубке котэ зарегаться туда можно в том числе и через pokerbitok а эту валюту можно намайнить если регулярно смотреть наши стримы по ссылкам выше все подробности в тгканале покерок httpstmepokerok_official',
#  'ритуал со свиданиями на новые отношения полная версия уже на моем youtubeканале по ссылке httpsyoutubeo6tovkagsg скидка на розовый кварц httpsozonrut9agdg77',
#  'рубрика разборы каждую среду в grishin club мои волшебные я возобновляю долгожданную для многих учеников и слушателей рубрику с разбором практических кейсов с раскладами каждую среду в grishin club мы будем разбирать с вами расклад тароленорманруны и тп из моей личной практики также мы будем разбирать сложные комбинации карт и всё о чём не напишут в книжках в среду утром я буду давать вам практический кейс который поможет вам углубить ваши трактовки умение преломить значения карт или рун под запрос а также развить необходимые для практика образное мышление и гибкость ума после разбора кейса в комментариях в grishin club я дам обратную связь по трактовке в течении пары дней без двоек троек четвёрок и пятёрок без осуждений только с полезными советами помощью и рекомендациями чтобы каждый из вас мог стать лучше и окрепнуть в практике а так же участники закрытого канала grishin club раз в неделю в специальном окошке могут размещать свои расклады для совместных трактовок и обсуждений условия фотография расклада четко сформулированный запрос любой расклад на 3 карты или любой другой расклад до пяти позиций вступить в секретный vip tgканал grishin club httpstmegrishin_club_vendor_bot инструкция к ботупродавцу grishin club bot httpsdocsgooglecomdocumentd1jagqqzcamgmt9oybgy3w9dz4fd2asjflewrrdgfrzeuedituspsharing до встречи в моем секретном клубе бесплатный марафон оракул ленорман за 3 секунды httpsalexeygrishincomorakullenorman3sec',
#  'ритуал со свиданиями на новые отношения полная версия уже на моем youtubeканале ссылка на канал httpswwwyoutubecomcalexeygrishintarot перейти по ссылке можно в шапке профиля или вбить вручную в поисковике на youtube alexeygrishintarot',
#  'ребята я все еще в отпуске но вышло шоу звездный дурак посмотрите его пожалуйста это одно из любимых и смешных шоу в которые я ходила потрясающий состав было весело у меня болели щеки httpsvkcccyqvob',
#  'httpstmesmossakovskiy3092 итоги евро с маэстро елагиным врывайтесь осторожно в выпуске много гарета саутгейта и сборной англии httpsyoutubenjd6k9pyb8usin3otilov5cpg0awu сообщение закреплено',
#  'итоги евро с маэстро елагиным врывайтесь осторожно в выпуске много гарета саутгейта и сборной англии httpsyoutubenjd6k9pyb8usin3otilov5cpg0awu п александр елагин итоги евро2024 это подкаст что делать за бонусом яркими эмоциями и азартом игры переходи по ссылке httpstmemossxec243 наш гость александр елагин подводим итоги евро осторожно в видео много гарета саутгейта и сборной англии евро2024 елагин мосс пишите в комментариях ваш вариант финальной пары и итоговый счет первый угадавший получит в подарок талисмана евро подкаст сделан в сотворчестве и соавторстве с александром францевым спасибо пабу три злые жены мичуринский пр 22 за гостеприимство если вы в москве и планируете выпить пива вам туда спасибо агентству симпл спорт за поддержку и дружескую помощь мой telegram канал httpstmemossakovskiy мой ingram httpswwwingramcommossakovskiy 0000 начало 0028 наш гость александр елагин 0250 футбол победил антифутбол как де ла фуэнте изменил сборную испании 0808 почему англичане в сборной менее ярко чем в клубах саутгейт 1205 гарет саутгейт талантливый убийца футбола или просто слабый тренер команда саутгейта могла стать великой 2100 евро2024 чемпионат уставших звезд 64 матча ямаля за сезон в 16 лет выдержит ли он 2540 о грамотном партнерстве 2632 кто лучший тренер турнира лучший игрок в чем магия родри 2808 почему елагин считает что турнир получился средним как изменилась сборная англии 2957 молодые таланты со скамейки сборной англии кто из них станет настоящей звездой 3235 оправдывает ли результат блеклую игру 3600 кого будет не хватать из тех кто заканчивает есть ли сейчас такие игроки как кроос и модрич 3942 должен ли роналду остаться в сборной поможет криштиану португалии на чм или потопит ее 4355 евро24 турнир без ярких звезд командное становится выше личного родри единственная суперзвезда 4613 феномен маленьких сборных раскрепощенные австрия турция грузия швейцария 5237 станет ли эта сборная испании командойдинастией 5805 благодарочки httpsyoutubenjd6k9pyb8usin3otilov5cpg0awu',
#  'buz_haus httpstmebuz_haus3411 легенда оля бузова нам до нее всем расти и расти алексей столяров в интервью youtubeканалу dr tochiev httpsyoutubecomwatchvxcxuequmussij1_ehbjvsz1dbb2w ольгабузова новостизвезд будниартиста',
#  'httpstmeizvestnose12382 коллеги из сэ где моя цитата что сборную англии должен возглавить александр мостовой который научит англичан играть в футбол какого хрена п как стало известно сэ дмитрий губерниев об уходе саутгейта из сборной англии им нужен тренер который научит их играть в футбол глобально пофиг конечно ушел и хрен с ним но если серьезно они же задачу не выполнили играют лучше с ним если с точки зрения результата смотреть но чтото постоянно идет не так с таким составом англичане справедливо надеялись на чтото большее чем финал поэтому англии нужен тренер который научит их играть в футбол понимаете саутгейт добился на европейской арене больше чем валерий лобановский по результату они серебряные медалисты чемпионата европы это достижение безусловно да поэтому саутгейт тренер хороший у него свое видение с мастеровитой клубной командой этот футбол может принести успех ну если конечно он не будет записывать музыкальный альбом с александрой трусовой тогда его спортивные дороги уведут совсем в другое место больше новостей на izvestnose httpstmeizvestnose12382',
#  'друзья наконецто это случилось я выложила стендап на ютуб надеюсь вам понравится подписывайтесь лайкайте комментируйте вот ссылка httpsmyoutubecomwatchvoh62vfb_vzu',
#  'sovsport httpstmesovsport19146 спартак бездарно профукал глушенкова колумнист совспорта дмитрий губерниев о тенденциях евро и рпл а намто какая польза футбол игра логичная тем не менее победила игра именно с большой буквы это главное поэтому я очень рад за испанцев и за вундеркинда ямаля люди доказывают что всётаки в футбол надо играть а не мучиться хотя повторю что всётаки я думал что выиграет англия кейн менее великим не стал много было разговоров о гарри кейне ведь он проиграл шесть финалов а после перехода в баварию и там не получилось выиграть командный трофей но давайте констатируем факт менее великимто он от этого не стал есть люди которым фатально не везёт с точки зрения тех или иных титулов но футболист же он классный глушенков сразу пришёлся ко двору игрок умный тонкий это прочувствовали сразу сильнейшие футболисты зенита и конечно в очередной раз вспоминается как его бездарно профукал московский спартак в своё время так не уметь разглядеть талант надо было умудриться галактионову нужно перестать быть плакучей ивой галактионову нужно работать и держать удар с моей точки зрения а не рассказывать где и что надо идти работать снимаю все имеющиеся шляпы так рыдать на скамейке после замены когда у тебя опухла нога и в бутсу уже не влезает может настоящий боец а главное спортсмен с большой буквы не обращайте внимания на жужжащих ос я попрежнему хочу сказать что я буду следить так или иначе за олимпиадой желаю всячески удачи тем людям которые туда поедут и очень надеюсь что мы с наградами вернёмся даже в таком малом составе эти люди они большие спортсмены они большие молодцы им нужна наша поддержка и те кто любит нашу страну понастоящему кто верит в россию в спорт они этих людей будут поддерживать мы этих людей поддержим колонку дмитрия читайте здесь подписывайтесь на sovsport',
#  'ребята квантовая психология ждет ваших отзывов комментариев лайков и брызгов иронии httpsyoutube_cqso8agowc',
#  'в гостях 111 мастодонт отечественного блогинга яркая и классная полина трубенкова ссылка httpsvkcccyqovo',
#  'йоу это случилось теперь я есть на ютуб в шапке профиля ссылка на мой стендап заходите смотрите смейтесь и лайкайте и комментируйте это обязательно спасибо за организацию съемки standup_msk спасибо съемку команде standup_view и отдельное спасибо за монтаж anna__protokovilo',
#  'недовольство собой и собственной внешностью отравляет жизнь миллионов девушек по всему миру и иногда эти комплексы заставляют решиться на отчаянный шаг лечь под нож пластического хирурга героиня нового выпуска шоу открытый прием екатерина стала жертвой пластического хирурга шокирующие детали операции поразили сотни тысяч человек по всей россии но виновник трагедии пластический хирург остался безнаказанным девушка пришла к нам на шоу чтобы рассказать свою историю и восстановить справедливость что заставляет нас делать пластические операции и как принять себя вместе со специалистом по телесно ориентированной терапии алексеем большаковым мы поможем разобраться героине в причинах недовольства собой полный выпуск по ссылке httpsyoutubeqvh4twy9kww',
#  'ребят вышел новый выпуск моей программы открытый прием хочу чтобы вы увидели историю девушки которая нарвалась не на профессионального врача а на мясника как психологически выбраться из такой сложной ситуации где тебя не только физически изуродовали но и морально смотрите на моем канале',
#  'смотрим новый влог господа ура тока пишите коменты там под видосом я же стараюсь снимаю оч хочется обратной связи новый влог',
#  'выдающийся титанический монументальный труд по разбору трилогии матрицы предположу что такой работы по анализу кинематографической единицы окей тринити тройки российский интернет еще не знал я серьезно на моем любимом ютубкиноканале чбу вышло пышное видео в котором ну я не знаю как это описать ребят погружение в самые недра сотнисотнисотни отсылок к мировой литературе духовным трактатам символам музыке интервью мнениям картинам фильмам текстам образам мультипликации оригинальным озвучке и сценариям практически покадровое исследование местами буквально по нотам впечатляющее почти нездоровое внимание к деталям это грандиозная работа я немного шокирован даже временами огромный ролик превращается в аттракцион который приближает тебя к пониманию замыслов семейки вачовски и тут же отталкивает фундаментальный разбор с немного обескураживающей но оттого еще более прекрасной концовкой все равно что посмотреть новую серию матрицы благо хрон такой же запаситесь временем оно того стоит приятного просмотра httpsyoutubenkoxzlf_ih4sisvbj3qmt9ccw84lx shhhnyakin п нео бог boosty httpsboostytothe46y полная версия видео на моём бусти telegram httpstmethe46y ingram httpswwwingramcomthe46y vk httpsvkcomnerdfacegroup основные треки из видео httpswwwyoutubecomf0x3r_fennec httpswwwyoutubecom4lienetic httpswwwyoutubecomvenustheory httpswwwyoutubecomkupla полный список ссылок и мелодий httpsdocsgooglecomdocumentd1kcczi5boi1kakr3m0lmmobjwfi_uxcnkx7dtmbcs4sedituspsharing 0000 0вступление 0053 1платон 0350 2декарт 0553 3бодрийяр 1522 4христианство 3119 5индуизм и буддизм 4241 6буддизм 5130 7индуизм 10031 8облачный атлас 10336 9мифология 10759 10эволюционная психология 13236 11душа 14029 12призрак в доспехах 14848 13алиса в стране чудес 14программы изгои в версии для boosty 15205 15дуализм попкультура отсылки вачовски 16теории в версии для boosty 15838 17что такое матрица httpsyoutubenkoxzlf_ih4sisvbj3qmt9ccw84lx',
#  'я и два самых красивых моих родственника сняли для вас новые позавчерашние новости',
#  'кто вчера не успелможете посмотреть на rutube там есть очень смешные моменты можете комментарии там ещё оставить хорошие',
#  'community_show httpstmecommunity_show1301 новый выпуск шоу ты кто такой у нас новая студия новый антураж но всё те же правила ребятам нужно узнать личную информацию о госте задавая только наводящие вопросы если они не справляются гость получает деньги сегодня угадываем информацию про ивана абрамова и девушку с анкетой 14 в студии расул чабдаров павел дедищев и витя алексеев ведущий гурам амарян приятного просмотра httpsvkcomvideo218471730_456239546 п ты кто такой 5 абрамовамаряндедищевчабдаровалексееванкета14 шоу в котором комики угадывают личную информацию о госте задавая при этом только наводящие вопросы за каждый неправильно угаданный факт гость забирает реальные деньги эксклюзивно в vk видео httpsvkcomvideo218471730_456239546',
#  'community_show httpstmecommunity_show1301 новый выпуск шоу ты кто такой у нас новая студия новый антураж но всё те же правила ребятам нужно узнать личную информацию о госте задавая только наводящие вопросы если они не справляются гость получает деньги сегодня угадываем информацию про ивана абрамова и девушку с анкетой 14 в студии расул чабдаров павел дедищев и витя алексеев ведущий гурам амарян приятного просмотра httpsvkcomvideo218471730_456239546 п ты кто такой 5 абрамовамаряндедищевчабдаровалексееванкета14 шоу в котором комики угадывают личную информацию о госте задавая при этом только наводящие вопросы за каждый неправильно угаданный факт гость забирает реальные деньги эксклюзивно в vk видео httpsvkcomvideo218471730_456239546',
#  'community_show httpstmecommunity_show1301 новый выпуск шоу ты кто такой у нас новая студия новый антураж но всё те же правила ребятам нужно узнать личную информацию о госте задавая только наводящие вопросы если они не справляются гость получает деньги сегодня угадываем информацию про ивана абрамова и девушку с анкетой 14 в студии расул чабдаров павел дедищев и витя алексеев ведущий гурам амарян приятного просмотра httpsvkcomvideo218471730_456239546 п ты кто такой 5 абрамовамаряндедищевчабдаровалексееванкета14 шоу в котором комики угадывают личную информацию о госте задавая при этом только наводящие вопросы за каждый неправильно угаданный факт гость забирает реальные деньги эксклюзивно в vk видео httpsvkcomvideo218471730_456239546',
#  'вчера у блестящего ильи трифанова был украден телеграм канал коллега трифанов и вот сообщение от трифанова сейчас украденный канал доступен по ссылке httpstmetjsygumcmgs4zwri мошенники пытаются развести людей на деньги прекратить это и вернуть канал можно только если на него массово пожалуется много людей прошу вас зайти и кинуть жалобу на канал сославшись на мошенничество заранее огромное спасибо',
#  'по итогам голосования гибкого супергероя зовут понтий пилатес хотя в душе он все равно стас а я вот куда ходила если кайф посмотрите httpsvkcomvideo214484275_456239954access_key94272e0e98f978db36 п аргументы путешественник еременко аранова ни швецов якушев аргументы спинофф шоу факты эксклюзивно в vk видео ведущие илья швецов александр якушев гости саша ни лиза варвара аранова лев еременко httpsvkcomvideo214484275_456239954access_key94272e0e98f978db36',
#  'девочки от души рекомендую канал про отношения его ведёт мужчина в формате без лица поэтому пишет жестко и честно это как подслушать мужской разговор о женщинах за бутылкой виски услышите то о чем не скажет ни один мужик глядя в глаза почитайте москоутиндер',
#  'пришло время прощаться мы наговорили столько добрых слов что директор дорогомиловского рынка прослезился и теперь николай писарев вернет гирю на базу мы будем скучать httpsyoutubeb6sxdphx2lufeatureshared п испания чемпион европы проклятие кейна итоги евро2024 че27 всем привет это че брат закрываем евро2024 финальным выпуском тимур гурцкая рома нагучев андрей аршавин александр дорский владислав радимов и николай писарев испания в ярком матче выиграла чемпионат европы как нам финал родри заслуженно получил лучшего игрока кто стал главным открытием турнира кукурелья уильямс почему проиграла англия гарет саутгейт должен был выпустить палмера в старте проклятие харри кейна всетаки существует кто теперь получит золотой мяч беллингем карвахаль кейн родри подвели все итоги выбрали лучших игроков главные открытия турнира и самые красивые голы смотрим наш телеграмканал httpstmeetofootballbro5405 наша группа вк httpsvkcometofootballbro почта для связи etofootballbratgmailcom по вопросам розыгрышей etokonkursbrogmailcom 000000 это че брат 000116 суперставки команды тимура на финал 000309 итоговые банки команд кто же выиграл 000646 почему первый тайм финала получился таким скучным 001552 потеря родри пошла на пользу испанцам 002248 первый гол в матче заслуга испанцев или ошибка англичан 002627 кто был лучшим игроком финала 003158 пример де ла фуэнте новый тренд в футболе 003607 а если бы англия сравняла в концовке 003846 как выглядел бы эчеб при замедленном youtube 004133 кем из супергероев были бы участники нашего цикла передач 004658 чем запомнились участники нашего цикла передач 005937 писарев mvp цикла передач 010207 называем лучших игроков евро по версии эчеб 011506 итоги фэнтезилиги 011557 прессконференция отвечаем на ваши вопросы 012158 прощаемся с нашими дорогими зрителями 012658 планируется продолжение цикла передач 012858 финальная байка от радимова этофутболбрат этофутболитоги этоитоги тимургурцкая гурцкая евро чемпионатевропы евро2024 футбол тактика премьерлига рпл трансферы испания германия франция португалия дорский александрдорский радимов владиславовдимов аршавин андрейаршавин писарев вадимписарев англия кейн беллингем фоден финалевро саутгейт роналду ямаль родри испания испанияанглия финал httpsyoutubeb6sxdphx2lufeatureshared',
#  'видео на канале httpsyoutubeharsz0ulcyksidqspltkgsmsaap0r',
#  'сходила с моей любимой беллой в гости к потрясающей варе было комфортно и весело обожаю этих девчонок посмотреть выпуск обязательно httpsvkcccyp9kc',
#  'смешнюнский выпуск с олей и беллой уже вышел httpsclckru3bubxh п в гостях у вари оля малащенко и белла малу авито путешествия всё пройдёт как забронировано и с кэшбэком бонусами httpsvkcccyiwcw erid 2vtzqusgkmf новые телевизоры sber line s httpsvkcccxliso erid 2vtzqx3euaz поддержим детей с тяжёлыми заболеваниями печени вместе с благотворительным фондом жизнь как чудо httpskakchudoruysclidlxukf5tluu300085505 httpsclckru3bubxh',
#  'здравствуйте ребята сегодня я познакомлю вас с тремя песнями которые будут выходить друг за другом я об этом ни где не рассказываю пока эксклюзив так скажем только тут в моем телеграмм канале итак начнем с песни давай ловить звезды песня написана мною наверное год или два назад время летит быстро изначально эта песня была сольная и текст в припеве был примерно такой ты не берешь трубку не перезваниваешь мне в ответ ты не берешь трубку к чему весь этот бред ты не берешь трубку и както время проходит зря ты не берешь трубку ну согласись это полная ерунда при создании аранжировки на эту песню я решил что это дуэтная композиция и захотелось переписать текст получилась милая романтическая история у меня вопрос к вам догадаетесь по голосу с кем же дуэт',
#  'владислав николаич в кабак пойдем в следующий раз испанию с победой косте геничу так откровенно топить за испанцев нельзя п владислав радимов владислав радимов о футболе и жизни делюсь личным мнением обсуждаю актуальные футбольные новости и вспоминаю яркие истории из прошлого httpstmevladradimov',
#  'httpsyoutubei2gcdmpyfei второй выпуск дачи',
#  'как снять венец безбрачия ритуал от одиночества бесплатный марафон оракул ленорман за 3 секунды httpsalexeygrishincomorakullenorman3sec',
#  'как снять венец безбрачия ритуал от одиночества бесплатный марафон оракул ленорман за 3 секунды httpsalexeygrishincomorakullenorman3sec прикреплённые ссылки httpsalexeygrishincomorakullenorman3sec',
#  'задача этой неделе в моем новом обучении по нумерологии прорабатывать 9ку так как я родилась 9 числа проявляться присваивать себе свои достижения и заявлять о себе миру постоянно это мне даётся через большой фильтр мало кто знает об этом моем интервью в программе судьба человека на канале россия 1 эфир был 21122022 прошло много времени а я стеснялась его выложить не нравилось как я выгляжу не нравился зажим который я в себе вижу не удалось сказать то что хотела в монтаж не вошло много что я считаю важным принимаю как урок благодарю что есть эта запись девочки за кадром огромное вам спасибо за море тепла и позитива посмотреть эфир можно по ссылке httpssmotrimruampvideo2533735',
#  'посмотрите мою первую тачку и напишите свою вот тут',
#  'опубликован комментарий к записи httpsvkcomwall161938332_7696 новый выпуск комедии с залом httpsvkcccymty3',
# ...
#  'самый сильный ритуал на старый новый год 13 января это повторение новогоднего желания праздничные скидки на информационные продукты денежные коды дракона карту желаний httpsalexeygrishincomnewyearsale праздничные скидки на магический магазин на ozon со свечами и браслетами httpsozonrutp29yp6k прикреплённые ссылки httpsalexeygrishincomnewyearsale',
#  'у тебя есть мечта здесь все про саморазвитие поэзию и психологию подписывайся на kesler_ksu рекомендации',
#  'я полюбил твоих демонов после здесь все про саморазвитие поэзию и психологию подписывайся на kesler_ksu рекомендации',
#  'самый сильный ритуал на старый новый год 13 января это повторение новогоднего желания праздничные скидки на информационные продукты денежные коды дракона карту желаний httpsalexeygrishincomnewyearsale праздничные скидки на магический магазин на ozon со свечами и браслетами httpsozonrutp29yp6k',
#  'stg_50 httpstmestg_501756 youtube удалил канал скользкий лед денис казанский андрей николишин сергей гимаевмл и тд как я понял ребята перекачивают пока выпуски сюда следим за развитием событий',
#  'таропрогноз на 3 января король пентаклей совет в целом карта описывает стабильную ситуацию и прочную основу для любых начинаний этот аркан вдохновляет реально оценивать ситуацию активно осуществлять задуманное и застраховать достигнутое он привносит с собой дух высшего качества во всё чего касается часто это предвестник продуктивной работы и многочисленных покупок когда сами идут в руки дорогие эксклюзивные вещи деньги это карта несомненного успеха в денежных вопросах если вы возьмёте на себя ответственность за использование своего капитала у вас есть все шансы достичь благополучия и процветания финансовая стабильность и уверенность крупный выигрыш наследство выгодные сделки стабильный доход любовь надежность зрелость и ответственность в отношениях с акцентом на защиту заботу и обладание король пентаклей описывает серьёзные продолжительные и зрелые связи между людьми обеспечивающими друг другу развитие благополучие социальный статус и уверенность в завтрашнем дне здесь сила страсти и инстинкт обладания уравновешивается и одновременно достигает полного развития типичный портрет короля пентаклей здоровый мужчина доверяющий инстинктам гурман и гедонист праздничные скидки на информационные продукты денежные коды дракона карту желаний httpsalexeygrishincomnewyearsale праздничные скидки на магический магазин на ozon со свечами и браслетами httpsozonrutp29yp6k',
#  'httpsyoutubeogmwi4j5vaesi7tz4h2twg_fx5cuh п большое шоу новогодний сезон реальный тизер смотрите 31 декабря каждый час с 1400 только в vk видео httpsvkcomazamatmusagaliev httpsyoutubeogmwi4j5vaesi7tz4h2twg_fx5cuh',
#  'torpedomoscow_fc httpstmetorpedomoscow_fc6286 заглянули сегодня в квартиру деда мороза и узнали кто ему пишет письма и какие желания просит исполнить наш100йгодначинается уже послезавтра п фк торпедо москва наш 100й год начинается попали в квартиру деда мороза 30 декабря когда он как раз читал письма от торпедовцев кто написал и что попросил смотрите в этом новогоднем видео httpsyoutubebmtz7h8xi28sipkhilxkyqii_eb5h',
#  'это тизер на 40 минут вечером эфир на 7 часов httpsyoutubehdoprseczdqsivbgs1dpqgbjkue8z п новогоднее застволье 2024 лучшие моменты cream soda николаев saluki бьянка михеева кассета полную версию новогоднего застволья смотрите 31 декабря в 2100 мск на канале stvol tv httpswwwyoutubecomstvoltelevision платите с помощью яндекс пэй скачивайте приложение и получайте дополнительный кэшбэк баллами плюса httpsclckru37j2e9 управляйте светом и другими приборами голосом или по расписанию умный дом с яндексом проще и дешевле чем кажется попробуйте httpsyaccmnqz5mll дорогие зрители чикен карри было приятно прочитать ваши поздравления родным близким и коллегам многие были довольно личные спасибо вам за доверие в нашем телеграмканале мы выложим ещё несколько зачитанных поздравлений httpstmechickencurryshow обнимаем с новым годом таймкоды 000 дан балан и миногарова организуют бал 218 the dawless кассета kino 359 смотрите stvol tv 31 декабря 505 поздравления с экрана 632 biicla polovinka мне нравится 820 я тя хрююю 927 репортаж аллы михеевой 1203 хороший папа 1304 бьянка были танцы 1455 маша миногарова про волшебство 1628 turbosh slowkick n96 пиво alblak 52 1823 брат говнюк 1902 стерео ширина торопыга 2037 предложение руки и сердца 2152 илья соболев комедиант 2350 поздравление уродам и друзьям 2427 акула кислотный диджей 2603 эщкере 2713 cream soda viby 2919 рыбауба 3023 воровайки хоп мусорок 3410 пинок под зад 3504 saluki огней 3805 ты не так много зарабатываешь 3914 игорь николаев выпьем за любовь httpsyoutubehdoprseczdqsivbgs1dpqgbjkue8z',
#  'а это вам подарочек httpsvkcomvideo110135406_456242810 п большое шоу 7 сезон первая серия покупайте выгодно на мегамаркете httpsclckru37ldae также используйте промокод большоешоу и получите дополнительную скидку 1 000 руб при первом заказе от 3 000 руб правила использования промокода httpsclckru37ldex erid 2vtzqwjmbau erid 2vtzqwrjdpq erid 2vtzqvyadkg в большом шоу httpsvkcomvideo110135406_456242810utm_sourcetgutm_mediumpostutm_termmqp_bigshowutm_content110135406_456242810utm_campaignvk_video',
#  'ну что погнали первая серия седьмого сезона большого шоу httpsvkcomwall110135406_121765 п азамат мусагалиев новогоднее большое шоупервая серия ну что всех с неумолимо наступающим новым годом мы начинаем наш безумный марафон смеха и веселья топовые комики секретный гость и впереди ещё целых пять выпусков новые серии каждый час финал в 1900 по москвеэксклюзивно в vk видео приятного просмотра httpsvkcomwall110135406_121765',
#  'продолжаем вторая серия седьмого сезона большого шоу httpsvkcomwall110135406_121923 п азамат мусагалиев новогоднее большое шоувторая серия новый год начал свой путь по стране камчатка чукотка с наступившим а мы продолжаем свой марафон большого шоу харламов и новые серии каждый час финал в 1900 по москвеэксклюзивно в vk видео приятного просмотра httpsvkcomwall110135406_121923',
#  'третья серия седьмого сезона большого шоу httpsvkcomwall110135406_122011 п азамат мусагалиев новогоднее большое шоутретья серия восточная якутия северные курилы с новым годом кто ещё только готовится встречать и рубит салатики не забудьте купить горошек марафон большого шоу продолжается новые серии каждый час финал в 1900 по москвеэксклюзивно в vk видео приятного просмотра httpsvkcomwall110135406_122011',
#  'четвёртая серия седьмого сезона большого шоу httpsvkcomvideo110135406_456242813 п большое шоу 7 сезон четвёртая серия покупайте выгодно на мегамаркете в декабре действует повышенный кешбэк до 80 бонусами httpsclckru37kkt5 также используйте промокод большоешоу и получите дополнительную скидку 1 000 рублей при первом заказе от 3 000 рублей правила использования промокода httpsclckru37kktv erid 2vtzqx2grc4 httpsvkcomvideo110135406_456242813',
#  'пятая серия седьмого сезона большого шоу httpsvkcomvideo110135406_456242814 п большое шоу 7 сезон пятая серия покупайте выгодно на мегамаркете в декабре действует повышенный кешбэк до 80 бонусами httpsclckru37kkvt также используйте промокод большоешоу и получите дополнительную скидку 1 000 рублей при первом заказе от 3 000 рублей правила использования промокода httpsclckru37kkx4 erid 2vtzqvu5r6u httpsvkcomvideo110135406_456242814',
#  'шестая серия седьмого сезона большого шоу финал httpsvkcomvideo110135406_456242816 п большое шоу 7 сезон шестая серия финал покупайте выгодно на мегамаркете httpsclckru37ldgh также используйте промокод большоешоу и получите дополнительную скидку 1 000 руб при первом заказе от 3 000 руб правила использования промокода httpsclckru37ldhv erid 2vtzqv6siay erid 2vtzqwqpmug в большом шоу главное требование httpsvkcomvideo110135406_456242816',
#  'смотрите чтобы в этом канале появились истории нам с вами надо собрать сколькото там голосов если кайф проголосуйте и у меня тут появятся истории вам несложно мне приятно httpstmeirinamyagkovboost п myagkova irina проголосуйте за канал чтобы он смог публиковать истории httpstmeirinamyagkovboost',
#  'ещё одну успели выпустить httpsyoutubea41ml9f4yxcsinmkzfcdejdms3zdn п судейская кхл заключительный в 2023 году выпуск судейской кхл все моменты в этом выпуске были предложены нашими зрителями ведущие владимир гучек алексей анисимов и леонид вайсфельд ________________ смотри все трансляции кхл httpsbitly3fkrq4n качай приложение кхл для ios httpsgooglasvy5u качай приложение кхл для android httpsgooglcifayu кхл судейская анисимов вайсфельд гучек httpsyoutubea41ml9f4yxcsinmkzfcdejdms3zdn',
#  'разговорное шоу о жизни в эмиграции руслан белый и ирина приходько рассуждают о разнице жизни в разных странах лёгкое шоу и минусах и плюсах в бытовой жизни руслан белый httpswwwingramcomruslan_belyy_ ирина приходько httpswwwingramcomirinozavr на платформе concertplacetv можно посмотреть концерты руслана белого и иры приходько standup стендап белый русланбелый приходько',
#  'ну что вот и подходит к концу этот год год взлетов и падений год радости и улыбок если честно то для меня он был безумно продуктивным чему я очень рада путешествия за границу проекты телевидение мероприятия новые знакомства и конечно же вы да что я рассказываю вы сами все видели каждый день мне кажется что за этот год я прожила все пять сложно да интересно безумно именно приятная усталость несет настоящую ценность в эту жизнь творите и верьте в себя верьте без веры никуда а я продолжаю дальше идти к своей цели кстати вкину вам одну новость в следующем году мы встретимся лично лично на моих концертах обняла подписывайся на kesler_ksu рекомендации',
#  'всем кулюм булюм httpsvkcomvideo211232966_456240094',
#  'братва начался стрим в тиктоке httpsvttiktokcomzsnnyopks всех жду',
#  'неудачные дубли хотите да такое редкое бывает но всё же бывает ловите маленький тизер блуперсов и неудачных дублей а полную версию можно посмотреть в нашем закрытом чате httpsboostytolazarevantonabout уписяетесь со смеху',
#  'братва стрим сегодня в 1900 по мск в тиктоке',
#  'насладитесь изысканным вкусом maccoffee cappuccino di torino httpsozonrutarrkzpm это старый выпуск можно ваш телефончик который еще не был представлен в youtube был в вк но там его почти ни кто не посмотрел такой бриллиант нам жалко терять и мы выкладываем его сейчас чтобы поднять вам настроение перед новым годом благодаря рекламе вы можете смотреть его бесплатно поэтому наслаждайтесь всем что увидите внутри приятного просмотра больше меня тут тг httpstmesobolevtelergam паблик вконтакет httpsvkcompublic161938332 по вопросам рекламы на моем канале commercialsobolevtutru по вопросам организации концертов нина 89119730246 смотри еще сольный концерт 2020 на тнт семья боль концерт можно посмотреть на платформе premier сольный концерт 2020 в поисках моей аудитории httpswwwyoutubecomwatchvt2uvhwgphr4 сольный концерт 2018 standup не на тнт httpswwwyoutubecomwatchv0yq9dcnpx1u концерт 2017 ходит по сцене и орет httpswwwyoutubecomwatchvgh6wq7jexck standup соболев стендап камеди comedy комик блог смешно sobolev прожарка соболь стэндап',
#  'а ещё посмотрите наш новогодний fonbetогонёк собрали почти всех амбассадоров поиграли выбрали проекты которые fonteam в 2024 году будет реализовывать смотреть тут httpswwwyoutubecomwatchvwtnvsfrfm6q',
#  'всё в этом году шутки кончились а песни в музыкальном фильме vk под шубой 2 нет поэтому завтра 29 декабря в 2024 встречаемся с вами в vk видео и настраиваемся на новогоднюю волну вместе реклама ооо в контакте инн 7842349892 erid 2vtzqw8lceg',
#  'новый выпуск мурашкина подкаст httpsyoutubetgwwwfvraja',
#  'мой youtube канал httpsyoutubecomvladislavcherevatyisiv4qsb_pdezgnztuj прикреплённые ссылки httpsyoutubecomvladislavcherevatyisiv4qsb_pdezgnztuj',
#  'итак друзья премьера года намечена на субботу 30 декабря artemmaltsev004 amromanov',
#  'это видео тронет вас до слез httpsyoutube7_55jc4fgi0',
#  'chappellepozvonit httpstmechappellepozvonit863 пока я смеюсь над шутками которые вы прислали мне в бот вы посмейтесь над отборными приколами от насти веневитиной из нового выпуска 10 смешных вещей из интернета это формат в котором люди которые смешат меня рассказывают о том что смешит их п настя веневитина 10 смешных вещей из интернета 1 когда все начинают делиться своими угарэсами я всегда вспоминаю про это видео меня в нем веселит то что столько нелепых событий происходят в один момент а еще подпись пса ограбили 2 фильм братья из гримсби очень много сортирного юмора яиц спермы и тд но гэгом с вентиляторами в конце он заслужил свое место в рейтинге 3 меня веселит вообще весь контент с животными я даже если честно подписана на аккаунт пуделя груши и на кота степана звучит тупо но я не знаю как с них можно не умиляться httpstelegraphnastyavenevitina10smeshnyhveshchejizinterneta1226',
#  'httpsvkcomwall27477591_65212 п иван абрамов сольный концерт ивана абрамова о самых важных девочках санктпетербург 2023 эксклюзивно в vk видео httpsvkcomwall27477591_65212',
#  'после этого видоса любой научится делать снежинки httpsrutuberuvideod82a874985f0b50dd6ecb89031788722 п битва снежинок как сделать самую новогоднюю снежинку оцениваем у кого лучше снежинка битва на скорость на похожесть и на ажурность httpsrutuberuvideod82a874985f0b50dd6ecb89031788722',
#  'ни к чему не стремись и всё устремится к тебе эфир от 211223 поддержать епифанцева финансово а так же посмотреть запись в хорошем качестве можно на бусти httpsboostytoepifania ℹ размер прикреплённого видеофайла превышает 150 мб',
#  'а вот и серхио рамос запел синебелоголубое небо испанец записал трек и даже выпустил клип с группой los yakis с учетом того что рамос родом с юга из севильи дебют получился ярко стилизованным в стиле любимого серхио фламенко httpsyoutubetzgvqjlahisiqm4wcikosqvagjvj akulininmatch п los yakis sergio ramos no me contradigas videoclip oficial sergioramos los yakis sergio ramos no me contradigas videoclip oficial los yakis se unen a sergioramos para regalarnos en estas navidades un tema que alegrará esta temporada festiva no me contradigas ya disponible en todas las plataformas musicales felices fiestas sigue a los yakis y a sergio ramos en todas sus cuentas los yakis ingram httpswwwingramcomlosyakisoficial tiktok httpswwwtiktokcomlosyakisoficial youtube httpswwwyoutubecomlosyakisoficial facebook httpswwwfacebookcomprofilephpid100057914388013 sergio ramos ingram httpswwwingramcomsergioramos tiktok httpswwwtiktokcomsergioramos youtube httpswwwyoutubecomchanneluc_ixbf2bwlwc9bxo7freisa facebook httpswwwfacebookcomsergioramosoficial director video benny terán ockam records sl felicesfiestas flamenco salsa httpsyoutubetzgvqjlahisiqm4wcikosqvagjvj',
#  'новые приключенцы уже в сети окунуться в мир странствий с нами можно тут',
#  'опубликован комментарий к записи httpsvkcomwall1950148_6025 httpsvkcomvideo220728319_456239150',
#  'подписывайтесь на мой телеграм канал теперь там будет интересно ну что вчера закончился один из лучших сезонов шоу звезды в африке и теперь я могу делиться с вами эксклюзивными кадрами с бэкстейджа httpstmegalustyanmichael397 прикреплённые ссылки httpstmegalustyanmichael397',
#  'киношники сегодня стрим в 1800 в тиктоке всех очень жду хочу рассказать свои впечатления от просмотра нового фильма',
#  'как вы мои хорошие все в такой же новогодней суматохе всю неделю а то и несколько сплю по 34 часа и я даже подумала что сейчас бы не помешал тур куданибудь далеко чтобы выспаться хотя бы в дороге может владивосток отличный вариант тем более что москва и владивосток стали одновременно победителями в голосовании на молодежную столицу россии 2024 и это значит что весь следующий год будет ярким сразу между двумя такими красивыми городами и свяжет всю нашу большую страну очень неожиданно и интересно как это пройдёт я люблю владивосток но конечно всегда выберу москву тут я живу тут я счастлива а какой город бы выбрали вы',
#  '25 юбилейный выпуск шоу кстати уже на vk ну и песенка новая хоккей группы obezyanavteploivode тоже там ну и тут теперь тоже',
#  'хоккей группа купание обезьяны в тёплой воде']

# %% [markdown]
# #### $2.2$
#
# **Удаление дубликатов.**
#
# Также ранее было обнаружено $6$ дубликатов, удалим их:

# %%
# Удаляем найденные дубликаты
text_df = text_df.drop_duplicates(subset = dupl_columns)


# Заново создаём маску дубликатов с помощью метода duplicated() и выводим количество оставшихся дубликатов
mask = text_df.duplicated(subset = dupl_columns)
train_duplicates = text_df[mask]
print(f'Число найденных дубликатов: {train_duplicates.shape[0]}')
# Out:
# Число найденных дубликатов: 0

# %% [markdown]
# ## <CENTER> **`3.` Разведывательный анализ данных (EDA)**
#
# В данной части проекта мы:
#
# * изучаем сгенерированный набор данных;
#
# * дополним наш анализ визуализациями, иллюстрирующими исследование.

# %% [markdown]
# #### $3.1$
#
# **Анализ длины текстов.**
#
# Создадим новые колонки для длины текстов в символах и словах. Подсчитаем основные статистики: среднюю длину, медиану, минимальную и максимальную длину:

# %%
# Подсчет длины текстов
text_df['text_length_chars'] = text_df['doc_text'].apply(len)
text_df['text_length_words'] = text_df['doc_text'].apply(lambda x: len(x.split()))



# Основные статистики
print('Статистики длины текстов:')
print('-' * 25)
print()

print(text_df[['text_length_chars', 'text_length_words']].describe())
print('-' * 50)
# Out:
# Статистики длины текстов:
# -------------------------
#
#        text_length_chars  text_length_words
# count        1000.000000        1000.000000
# mean          483.030000          63.351000
# std           698.470161          97.465827
# min             8.000000           1.000000
# 25%           116.750000          14.000000
# 50%           219.000000          26.000000
# 75%           546.250000          69.000000
# max          8146.000000        1092.000000
# --------------------------------------------------

# %% [markdown]
# Так же вычислим тексты, которые слишком короткие (например, < $5$ символов) или слишком длинные (например, > $1000$ слов). Проверим, являются ли короткие тексты пропусками или неинформативными (например, `"нет"`, `"ок"`):

# %%
# Проверка аномалий
short_texts = text_df[text_df['text_length_chars'] < 5]
long_texts = text_df[text_df['text_length_words'] > 1000]

# Выводим результат
print(f'Короткие тексты ( < 5 символов): {len(short_texts)}')
print(f'Длинные тексты ( > 1000 слов): {len(long_texts)}')
# Out:
# Короткие тексты ( < 5 символов): 0
# Длинные тексты ( > 1000 слов): 1

# %% [markdown]
# Построим гистограмму длины текстов в словах и символах. Так же создадим коробчатую диаграмму (boxplot) для выявления выбросов:

# %%
# Задаём заглавие для гистограммы
print('-' * 150)
print('Гистограмма длины текстов в словах и символах:')

# Визуализация длины текстов
plt.figure(figsize = (30, 15))
sns.histplot(text_df['text_length_words'], bins=30, kde=True, color='green')
plt.title('Распределение длины текстов (в словах)', fontsize = 20)
plt.xlabel('Количество слов', fontsize = 15)
plt.ylabel('Частота', fontsize = 15)
plt.grid(True, linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()
print('-' * 150)




# Boxplot для выбросов
print('Коробчатая диаграмма выбросов:')

plt.figure(figsize = (30, 15))
sns.boxplot(x=text_df['text_length_words'], color='lightblue')
plt.title('Boxplot длины текстов (в словах)', fontsize = 20)
plt.xlabel('Количество слов', fontsize = 15)
plt.grid(True, linestyle = '--', alpha = 0.7)
plt.show()
print('-' * 150)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Гистограмма длины текстов в словах и символах:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Коробчатая диаграмма выбросов
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### $3.2$
#
# **Анализ текстового содержимого.**
#
# Разбобъём тексты на слова, затем удалим стоп-слова и знаки препинания. После чего подсчитаем общее количество слов и уникальных слов (словарный запас):

# %%
# Токенизация и очистка
stop_words = set(stopwords.words('russian'))
all_words = []

for text in text_df['doc_text']:
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in stop_words]
    all_words.extend(tokens)



# Подсчет частоты слов
word_freq = Counter(all_words)
common_words = word_freq.most_common(10)



# Выводим результат
print(f'Топ-10 слов: {common_words}')
# Out:
# Топ-10 слов: [('https', 1807), ('это', 329), ('п', 246), ('выпуск', 152), ('видео', 134), ('канал', 118), ('новый', 112), ('шоу', 105), ('очень', 101), ('моем', 93)]

# %% [markdown]
# Выведем 'Топ-10' биграмм:

# %%
# Биграммы
bigrams = list(ngrams(all_words, 2))
bigram_freq = Counter(bigrams).most_common(10)


# Выводим результат
print(f'Топ-10 биграмм: {bigram_freq}')
# Out:
# Топ-10 биграмм: [(('https', 'п'), 190), (('https', 'https'), 182), (('grishin', 'club'), 79), (('прикреплённые', 'ссылки'), 56), (('ссылки', 'https'), 52), (('ссылке', 'https'), 51), (('сольный', 'концерт'), 46), (('новый', 'выпуск'), 41), (('https', 'прикреплённые'), 36), (('telegram', 'https'), 34)]

# %% [markdown]
# Строим таблицу биграмм:

# %%
# Токенизация и очистка текстов
stop_words = set(stopwords.words('russian'))
all_words = []

for text in documents:
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in stop_words]
    all_words.extend(tokens)



# Формирование биграмм
bigrams = list(ngrams(all_words, 2))
bigram_freq = Counter(bigrams).most_common(10)

# Подготовка данных для таблицы
bigram_list = [(f"{bigram[0]} {bigram[1]}", count) for bigram, count in bigram_freq]
bigram_df = pd.DataFrame(bigram_list, columns=['Биграмма', 'Частота'])

# Вывод таблицы
print('Таблица топ-10 биграмм:')
print('-' * 20)
print()

print(bigram_df)
# Out:
# Таблица топ-10 биграмм:
# --------------------
#
#                Биграмма  Частота
# 0               https п      190
# 1           https https      182
# 2          grishin club       79
# 3  прикреплённые ссылки       56
# 4          ссылки https       52
# 5          ссылке https       51
# 6       сольный концерт       46
# 7          новый выпуск       41
# 8   https прикреплённые       36
# 9        telegram https       34

# %% [markdown]
# Строим график:

# %%
# Задаём заглавие для гистограммы
print('-' * 150)
print('Гирафик наиболее частых биграмм:')


# Задаём размер графика
plt.figure(figsize = (30, 15))

# Строим график
sns.barplot(
    data = bigram_df,
    x = 'Частота', 
    y = 'Биграмма', 
    palette = 'viridis'
)

# Настраиваем оформление
plt.title('Топ-10 биграмм по частоте', fontsize = 20)
plt.xlabel('Частота', fontsize = 15)
plt.ylabel('Биграмма', fontsize = 15)
plt.grid(True, linestyle = '--', alpha = 0.7)
plt.tight_layout()

# Отображаем график
plt.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Гирафик наиболее частых биграмм:

# %% [markdown]
# Теперь Построим облако слов (`wordcloud`) для всех текстов. Так же создадим график топ-10 самых частых слов:

# %%
# Задаём заглавие для гистограммы
print('-' * 150)
print('Облако (wordcloud) слов:')

# Облако слов
wordcloud = WordCloud(
    width = 1200, 
    height = 600, 
    background_color = 'white'
).generate(' '.join(all_words))

plt.figure(figsize = (30, 15))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Облако слов для текстов', fontsize = 20)
plt.show()
print('-' * 150)




# График частоты слов
print('График частоты слов:')

plt.figure(figsize = (30, 15))
sns.barplot(
    x = [count for word, count in common_words], 
    y = [word for word, count in common_words]
)

plt.title('Топ-10 самых частых слов', fontsize = 20)
plt.xlabel('Частота', fontsize = 15)
plt.ylabel('Слово', fontsize = 15)
plt.grid(True, linestyle = '--', alpha = 0.7)
plt.tight_layout()
plt.show()
print('-' * 150)

plt.show()
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Облако (wordcloud) слов:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# График частоты слов:
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### $3.3$
#
# Выявим ключевые слова и фразы, для этого используем `KeyBERT` для извлечения ключевых слов из каждого текста:

# %%
# Инициализация модели KeyBERT
kw_model = KeyBERT()


# Извлечение ключевых слов
keywords = []
for text in text_df['doc_text']:
    kws = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 2), stop_words='russian')
    keywords.append([kw[0] for kw in kws[:2]])  # Берем топ-2 ключевых слова

# Добавление ключевых слов в DataFrame
text_df['keywords'] = keywords



# Вывод результатов
print('Примеры ключевых слов:')
print('-' * 25)
print()

print(text_df[['doc_text', 'keywords']].head())
print('-' * 65)
# Out:
# Примеры ключевых слов:
# -------------------------
#
#                                             doc_text keywords
# 0  Твой лучший секс спрятан здесь 🔞  Делюсь канал...       []
# 1  ⭐️  Кнопка: ⭐️START⭐️(https://t.me/major/start...       []
# 2  А продолжение где? Правильно. В моем сообществ...       []
# 3  Тем временем моя авторская телега уверенно в т...       []
# 4  У меня есть двоюродная сестра, у нее есть сын ...       []
# -----------------------------------------------------------------

# %% [markdown]
# ## <CENTER> **`4.` Machine Learning**
#
# На данном этапе мы будем использовать подход с `SentenceTransformer` для обработки текста, чтобы выполнить лемматизацию и поиск позиций.

# %% [markdown]
# #### $4.1$
#
# Загружаем модель:

# %%
# Загружаем модель sentence-transformers
ST_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
print('Модель загружена')
# Out:
# Модель загружена

# %% [markdown]
# #### $4.2$
#
# Создаём функцию для организации поиска:

# %%
# Функция для поиска наиболее близкого слова в документе
def semantic_search_in_document(document, query, model):
    
    
    """
    Ищет слово в документе, наиболее близкое по смыслу к заданному запросу.

    Args:
        document (str): Строка (документ), в которой выполняется поиск.
        query (str): Запрос (словосочетание) для поиска.
        model: Модель sentence-transformers для создания эмбеддингов.

    Returns:
        dict: Словарь с результатами поиска:
            - "document": Исходный документ.
            - "score": Вероятность совпадения (от 0 до 1).
            - "positions": Позиции найденного слова в формате (start-end) в символах.
            - "matched_word": Найденное слово.
    """
    
    # Функция для очистки текста
    def clean_text(text):
        text = text.lower()
        text = re.sub(r'[^\w\s]', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    
    
    doc_cleaned = clean_text(document)
    query_cleaned = clean_text(query)
    
    doc_words = doc_cleaned.split()
    query_words = query_cleaned.split()
    
    
    # Проверка на длину запроса
    if len(query_words) > 2:
        return {
            'document': document,
            'distance': 1.0,
            'positions': '0-0',
            'matched_word': ''
        }
    
    
    # Получаем эмбеддинги для всего документа и запроса
    doc_embedding = model.encode(doc_cleaned, convert_to_tensor=True)
    query_embedding = model.encode(query_cleaned, convert_to_tensor=True)
    
    # Вычисляем косинусное сходство между запросом и документом
    cosine_similarity = util.cos_sim(query_embedding, doc_embedding)[0]
    
    # Косинусное расстояние = 1 - косинусное сходство
    cosine_distance = 1.0 - cosine_similarity
    
    
    # Если косинусное расстояние слишком большое (> 0.5), запрос не связан с документом
    if cosine_distance > 0.5:
        return {
            'document': document,
            'distance': float(cosine_distance),
            'positions': '0-0',
            'matched_word': ''
        }
    
    
    # Находим ближайшее слово для определения позиции
    doc_words_embeddings = model.encode(doc_words, convert_to_tensor=True)
    word_cosine_scores = util.cos_sim(query_embedding, doc_words_embeddings)[0]
    best_word_idx = np.argmax(word_cosine_scores)
    best_word = doc_words[best_word_idx]
    
    # Определяем позиции найденного слова
    start_pos = document.lower().find(best_word)
    end_pos = start_pos + len(best_word) if start_pos != -1 else 0
    positions_str = f"{start_pos}-{end_pos}" if start_pos != -1 else "0-0"
    
    
    return {
        'document': document,
        'distance': float(cosine_distance),
        'positions': positions_str,
        'matched_word': best_word
    }

# %% [markdown]
# #### $4.3$
#
# Организовываем поиск:

# %%
# Заданные списки строк (документы) и словосочетаний
documents = [
    'доченька твоя совсем большая стала',
    'в лесу растёт высокое дерево',
    'портфель лежит в шкафу дома',
    'институт находится в центре города',
    'вся дорога забита деревьями и цветами',
    'в следующее воскресенье я собираюсь в питер',
    'у меня сломалась стиралка прикинь',
    'садись в машину и поехали уже',
    'сколько стоит ремонт стиральной машины',
    'ты возьми корзину прежде чем набрать продукты',
    'его сегодня утром отвезли в ближайший госпиталь'
]


queries = [
    'дочь',
    'дерево',
    'портфель',
    'институт',
    'дерево',
    'санкт петербург',
    'стиральная машина',
    'автомобиль',
    'автомобиль',
    'звонить',
    'больница'
]



# Проверяем, что длины списков совпадают
assert len(documents) == len(queries), 'Длина списков documents и queries должна совпадать!'

# Выполняем поиск
results = []
for doc, query in zip(documents, queries):
    result = semantic_search_in_document(doc, query, ST_model)
    
    # Добавляем результат только если косинусное расстояние <= 0.5
    if result['distance'] <= 0.5:
        short_doc = result['document'][:50] + "..." if len(result['document']) > 50 else result['document']
        results.append({
            'документ': short_doc,
            'словосочетание': query,
            'позиция': result['positions'],
            'косинусное_расстояние': result['distance']
        })



# Выводим результаты
print('Результат работы модели:')
print('-' * 30)
print()

print('ДОКУМЕНТ'.ljust(50), 'СЛОВОСОЧЕТАНИЕ'.ljust(20), 'ВЫВОД')
for res in results:
    print(
        res['документ'].ljust(50),
        res['словосочетание'].ljust(20),
        f"позиция: {res['позиция']}".ljust(25),
        f"косинусное расстояние: {res['косинусное_расстояние']:.3f}"
    )

print('-' * 130)
# Out:
# Результат работы модели:
# ------------------------------
#
# ДОКУМЕНТ                                           СЛОВОСОЧЕТАНИЕ       ВЫВОД
# доченька твоя совсем большая стала                 дочь                 позиция: 0-8              косинусное расстояние: 0.412
# в лесу растёт высокое дерево                       дерево               позиция: 22-28            косинусное расстояние: 0.212
# портфель лежит в шкафу дома                        портфель             позиция: 0-8              косинусное расстояние: 0.256
# институт находится в центре города                 институт             позиция: 0-8              косинусное расстояние: 0.466
# вся дорога забита деревьями и цветами              дерево               позиция: 18-27            косинусное расстояние: 0.495
# садись в машину и поехали уже                      автомобиль           позиция: 9-15             косинусное расстояние: 0.368
# его сегодня утром отвезли в ближайший госпиталь    больница             позиция: 38-47            косинусное расстояние: 0.397
# ----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### $4.4$
#
# Сохраняем полученную результаты:

# %%
# Сохраняем модель
os.makedirs('ST_model', exist_ok=True)
joblib.dump(results, 'ST_model/search_results.pkl')


# Сохраняем модель в папку ST_model/
os.makedirs('ST_model', exist_ok = True)  # Создаём папку, если её нет
ST_model.save('ST_model/semantic_search_model')
print('Модель сохранена в ST_model/semantic_search_model')



# Проверяем, существует ли сохранённая модель
if os.path.exists('ST_model/semantic_search_model'):
    ST_model = SentenceTransformer('ST_model/semantic_search_model')
    print('Модель загружена из локального файла')
    
else:
    ST_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
    print('Модель загружена из интернета')
    
    os.makedirs('ST_model', exist_ok = True)
    ST_model.save('ST_model/semantic_search_model')
    print('Модель сохранена в ST_model/semantic_search_model')
# Out:
# Модель сохранена в ST_model/semantic_search_model
# Модель загружена из локального файла
